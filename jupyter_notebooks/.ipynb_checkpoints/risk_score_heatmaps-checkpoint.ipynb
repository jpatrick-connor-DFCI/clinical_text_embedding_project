# %%
import os
import warnings
import pandas as pd
import numpy as np
from joblib import Parallel, delayed, parallel_backend
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler
from sksurv.linear_model import CoxPHSurvivalAnalysis
from sksurv.metrics import concordance_index_censored
import matplotlib.pyplot as plt
import seaborn as sns

# =====================
# Config / Options
# =====================
pd.options.mode.chained_assignment = None  # suppress SettingWithCopy warnings

# Paths
PROJECT_PATH = '/data/gusev/USERS/jpconnor/clinical_text_project/'
DATA_PATH = os.path.join(PROJECT_PATH, 'data/')
SURV_PATH = os.path.join(DATA_PATH, 'survival_data/')
RESULTS_PATH = os.path.join(SURV_PATH, 'results/')
NOTES_PATH = os.path.join(DATA_PATH, 'batched_datasets/VTE_data/processed_datasets/')
STAGE_PATH = '/data/gusev/PROFILE/CLINICAL/OncDRS/DERIVED_FROM_CLINICAL_TEXTS_2024_03/derived_files/cancer_stage/'
OUTPUT_PATH = os.path.join(RESULTS_PATH, 'phecode_model_comps')
HELD_OUT_PRED_PATH = os.path.join(RESULTS_PATH, 'phecode_held_out_preds')
FIGURE_PATH = os.path.join(PROJECT_PATH, 'figures/')
os.makedirs(OUTPUT_PATH, exist_ok=True)

events = [file.split('_')[0] for file in os.listdir(HELD_OUT_PRED_PATH)]

def evaluate_risk_model_cv(event, data_path=HELD_OUT_PRED_PATH, n_splits=5, n_permutations=5, random_state=42):
    df = pd.read_csv(os.path.join(data_path, event + '_cv_preds.csv'))
    
    duration_col = f"tt_{event}"
    event_col = event
    features = ["text_risk_score", "stage_type_risk_score", "ehr_risk_score", "genomics_risk_score"]

    # Drop NA rows
    subset = df.dropna(subset=[duration_col, event_col] + features)

    X = subset[features].reset_index(drop=True)
    y = np.array(
        [(bool(e), t) for e, t in zip(subset[event_col], subset[duration_col])],
        dtype=[('event', '?'), ('duration', 'f8')]
    )

    kf = KFold(n_splits=n_splits, shuffle=True, random_state=random_state)

    cindices = []
    coefs = []
    perm_drops = {feat: [] for feat in features}

    for train_idx, test_idx in kf.split(X):
        X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
        y_train, y_test = y[train_idx], y[test_idx]

        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train)
        X_test_scaled = scaler.transform(X_test)

        model = CoxPHSurvivalAnalysis()
        model.fit(X_train_scaled, y_train)

        preds = model.predict(X_test_scaled)
        base_cindex = concordance_index_censored(y_test["event"], y_test["duration"], preds)[0]
        cindices.append(base_cindex)
        coefs.append(model.coef_)

        # Permutation importance
        for feat in features:
            drops = []
            for _ in range(n_permutations):
                X_test_perm = X_test.copy()
                X_test_perm[feat] = np.random.permutation(X_test_perm[feat].values)
                X_test_perm_scaled = scaler.transform(X_test_perm)
                perm_preds = model.predict(X_test_perm_scaled)
                perm_cindex = concordance_index_censored(y_test["event"], y_test["duration"], perm_preds)[0]
                drops.append(base_cindex - perm_cindex)
            perm_drops[feat].append(np.mean(drops))

    # Aggregate results
    mean_cindex = np.mean(cindices)
    mean_coefs = np.mean(np.array(coefs), axis=0)
    mean_perm_importance = {feat: np.mean(perm_drops[feat]) for feat in features}

    # Clean feature names by removing "_risk_score"
    clean_features = [feat.replace("_risk_score", "") for feat in features]

    # Map permutation importances to clean names
    mean_perm_importance_clean = {
        clean_feat: mean_perm_importance[orig_feat]
        for clean_feat, orig_feat in zip(clean_features, features)
    }

    # Determine most important clean feature
    most_important_feat = max(mean_perm_importance_clean, key=mean_perm_importance_clean.get)

    result = {
        "event": event,
        "cindex": mean_cindex,
        **{f"coef_{clean_feat}": mean_coefs[i] for i, clean_feat in enumerate(clean_features)},
        **{f"perm_{clean_feat}": mean_perm_importance_clean[clean_feat] for clean_feat in clean_features},
        "most_important_feature": most_important_feat
    }

    return result

# %%
results = Parallel(n_jobs=-1, backend="loky")(  # uses all CPUs
    delayed(evaluate_risk_model_cv)(event) for event in events
)
final_results_df = pd.DataFrame(results)
final_results_df = final_results_df.loc[final_results_df['event'] != '8.0']
# Out:
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.6877e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.49653e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.10689e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.56625e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.26224e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.18115e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.35348e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.41252e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.36322e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.02205e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.22333e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.80731e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.89719e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.6289e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.95553e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.76615e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.67985e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.16992e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.18523e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.54495e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.52271e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.62256e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.44872e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.99627e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.96351e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.98899e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.46029e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.36764e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.82953e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.66851e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.73996e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.36746e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.58134e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.8817e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.06927e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.11845e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.74642e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.27974e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.1883e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.45726e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.52475e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.26873e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.40774e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.84572e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.76502e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.27255e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.42186e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.71935e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.56637e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.22108e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.83177e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.62106e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.58053e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.62265e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.50885e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.24625e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.68029e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.1295e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.61197e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.15185e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.51994e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.56629e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.52209e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.80649e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.79731e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.60047e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.82476e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.0034e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.52145e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.46103e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.01665e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.57326e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.12651e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.09981e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.92253e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.95638e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.43133e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.03652e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.71981e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.57142e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.33274e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.55244e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.93702e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.6534e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.05235e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.322e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.98791e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.71152e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.97197e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.14949e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.49936e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.61039e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.41493e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.2658e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.95815e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.06829e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.11652e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.63049e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.75715e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.83262e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /tmp/ipykernel_67862/3689520610.py:63: ConvergenceWarning: Optimization did not converge: Maximum number of iterations has been exceeded.
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.77728e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.07646e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.31936e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.5888e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.63987e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.39517e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.6673e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.65897e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.39664e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.41937e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.95565e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.6883e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.91401e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.81945e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.49933e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.74339e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.32155e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.20769e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39431e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.64791e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.49265e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.58599e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.28341e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.73408e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39422e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.31025e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.87783e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.39861e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.12494e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.87564e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.22412e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.85626e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.28029e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.79584e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.43905e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.84549e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.13484e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.5114e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.94656e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.47041e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.26612e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39179e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.62892e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.54252e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.45619e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.36871e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.97288e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.69452e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.18336e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.27102e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.46978e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.16364e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.39351e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.19311e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.52203e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.83817e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.40778e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30602e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.6846e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.3099e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.19391e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.94941e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.34287e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.42337e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.71073e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.12104e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.30048e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.4074e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.3934e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.69908e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.84628e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.07362e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.07377e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.35458e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.11318e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.46607e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39049e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.69792e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.93607e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39448e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.30199e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.08048e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.78636e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.96814e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.97754e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39159e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39389e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.92747e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.39249e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.25119e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.20419e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.14566e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.06984e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.77698e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# ...
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.43248e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.60228e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.60191e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=9.72719e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.75201e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.45123e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.44409e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.70308e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.16412e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.13867e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.95697e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.08522e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.02942e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.15974e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.95567e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.90047e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.20415e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.23962e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.71174e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.73085e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.01473e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.38674e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.31291e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.95507e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.50924e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.99798e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.83431e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.89078e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.5351e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.76581e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.05745e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.57092e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.02031e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.90387e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.5546e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.82551e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.80572e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.1745e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.89025e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.10355e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.28307e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.85337e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.87156e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.9798e-36): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.93535e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.38928e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.56452e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.09126e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.50056e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.1713e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.37644e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.07935e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.76662e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.42024e-35): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.08119e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.08063e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.04396e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.01022e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.60857e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.86226e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.6966e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.62472e-33): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.98954e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.05267e-34): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /tmp/ipykernel_67862/3689520610.py:63: ConvergenceWarning: Optimization did not converge: Maximum number of iterations has been exceeded.

# %%
final_results_df['most_important_feature'].value_counts()
# Out:
# most_important_feature
# text          100
# stage_type      6
# ehr             6
# genomics        2
# Name: count, dtype: int64

# %%
# Set 'event' as index and keep only importance columns
importance_cols = ['perm_text', 'perm_ehr', 'perm_genomics', 'perm_stage_type']
heatmap_data = final_results_df.set_index('event')[importance_cols]

# Optional: Normalize each row (event) to better visualize relative importance
# heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)

# Clustered heatmap
g = sns.clustermap(
    heatmap_data,
    method='average',
    metric='euclidean',
    cmap='viridis',
    annot=False,
    figsize=(12, max(8, len(heatmap_data) *0.1)),  # Dynamically size based on number of events
    cbar_kws={"label": "Feature Importance"},
    linewidths=0
)
g.ax_heatmap.set_yticklabels([])
g.ax_heatmap.yaxis.set_ticks([])
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), fontsize=16)
g.ax_heatmap.set_ylabel('')
plt.suptitle("Clustered Heatmap of Risk Score Importances Across All Events", fontsize=20, y=1.02)

g.fig.savefig(os.path.join(FIGURE_PATH, 'risk_score_models/all_risk_score_feature_importances_clustermap.png'), dpi=300, bbox_inches='tight')
plt.close()

top40_df = final_results_df.sort_values(by='cindex', ascending=False).head(40)

icd_to_phecode_map = pd.read_csv(os.path.join(DATA_PATH, 'code_data/icd_to_phecode_map.csv'))
phecode_descr_dict = dict(zip(icd_to_phecode_map['PHECODE'].astype(str), icd_to_phecode_map['PHECODE_DESCR'].astype(str)))

top40_df['event_descr'] = top40_df['event'].apply(lambda x : phecode_descr_dict[x] if x in phecode_descr_dict.keys() else x)

heatmap_data = top40_df.set_index('event_descr')[importance_cols]

# Optional: Normalize each row (event) to better visualize relative importance
# heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)

# Clustered heatmap
g = sns.clustermap(
    heatmap_data,
    method='average',
    metric='euclidean',
    cmap='viridis',
    annot=True,
    fmt='.2f',
    figsize=(18, max(8, len(heatmap_data) *0.4)),  # Dynamically size based on number of events
    cbar_kws={"label": "Feature Importance"},
    linewidths=0
)
g.fig.suptitle("Clustered Heatmap of Risk Score Importances Across Top 40 Events by C-Index", fontsize=20, y=1.02)
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), fontsize=16)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.fig.savefig(os.path.join(FIGURE_PATH, 'risk_score_models/top_40_risk_score_feature_importances_clustermap.png'), dpi=300, bbox_inches='tight')
plt.close()

# %%
# Set 'event' as index and keep only importance columns
importance_cols = ['coef_text', 'coef_ehr', 'coef_genomics', 'coef_stage_type']
heatmap_data = final_results_df.set_index('event')[importance_cols]

# Optional: Normalize each row (event) to better visualize relative importance
# heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)

# Clustered heatmap
g = sns.clustermap(
    heatmap_data,
    method='average',
    metric='euclidean',
    cmap='viridis',
    annot=False,
    figsize=(12, max(8, len(heatmap_data) *0.1)),  # Dynamically size based on number of events
    cbar_kws={"label": "Coefficient"},
    linewidths=0
)
g.ax_heatmap.set_yticklabels([])
g.ax_heatmap.yaxis.set_ticks([])
g.ax_heatmap.set_ylabel('')
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), fontsize=16)
plt.suptitle("Clustered Heatmap of Risk Score Coefficients Across All Events", fontsize=20, y=1.02)

g.fig.savefig(os.path.join(FIGURE_PATH, 'risk_score_models/all_risk_score_coefficients_clustermap.png'), dpi=300, bbox_inches='tight')
plt.close()

# %%
top40_df = final_results_df.sort_values(by='cindex', ascending=False).head(40)
top40_df['event_descr'] = top40_df['event'].apply(lambda x : phecode_descr_dict[x] if x in phecode_descr_dict.keys() else x)

heatmap_data = top40_df.set_index('event_descr')[importance_cols]

# Optional: Normalize each row (event) to better visualize relative importance
# heatmap_data = heatmap_data.div(heatmap_data.sum(axis=1), axis=0)

# Clustered heatmap
g = sns.clustermap(
    heatmap_data,
    method='average',
    metric='euclidean',
    cmap='viridis',
    annot=True,
    fmt='.2f',
    figsize=(18, max(8, len(heatmap_data) *0.4)),  # Dynamically size based on number of events
    cbar_kws={"label": "Coefficient"},
    linewidths=0
)
g.fig.suptitle("Clustered Heatmap of Risk Score Coefficients Across Top 40 Events by C-Index", fontsize=20, y=1.02)
g.ax_heatmap.set_xticklabels(g.ax_heatmap.get_xticklabels(), fontsize=16)
g.ax_heatmap.set_yticklabels(g.ax_heatmap.get_yticklabels(), fontsize=16)

g.fig.savefig(os.path.join(FIGURE_PATH, 'risk_score_models/top_40_risk_score_coefficients_clustermap.png'), dpi=300, bbox_inches='tight')
plt.close()

# %%
phecode_descr_dict['783.0']
# Out:
# 'Fever of unknown origin'
