# %%
# === Imports ===
import os
import icd10
import time
from lifelines import CoxPHFitter
from lifelines.utils import concordance_index
from tqdm import tqdm
import numpy as np
import pandas as pd
from functools import reduce
from sklearn.preprocessing import StandardScaler
from embed_surv_utils import run_grid_CoxPH_parallel, get_heldout_risk_scores_CoxPH

# === Paths ===
PROJ_PATH = '/data/gusev/USERS/jpconnor/clinical_text_project/'
FIGURE_PATH = os.path.join(PROJ_PATH, 'figures/model_metrics/')
DATA_PATH = os.path.join(PROJ_PATH, 'data/')
SURV_PATH = os.path.join(DATA_PATH, 'survival_data/')
RESULTS_PATH = os.path.join(SURV_PATH, 'results/')
FEATURE_PATH = os.path.join(DATA_PATH, 'clinical_and_genomic_features/')
FULL_COHORT_PATH = os.path.join(RESULTS_PATH, 'icd10_level_3_full_cohort/')
FEATURE_COMPS_PATH = os.path.join(RESULTS_PATH, 'icd10_level_3_complete_model/')
HELD_OUT_PATH = os.path.join(RESULTS_PATH, 'icd10_level_3_held_out_preds/')
os.makedirs(HELD_OUT_PATH, exist_ok=True)

events = list(set(os.listdir(FULL_COHORT_PATH)) & set(os.listdir(FEATURE_COMPS_PATH)))
data_cols = ['DFCI_MRN'] + events + [f'tt_{event}' for event in events]

tte_df = pd.read_csv(os.path.join(SURV_PATH, 'time-to-icd/time_decayed_events_df.csv'), usecols=data_cols)

event_descrs = []; event_chapters = []; event_block_descrs = [];
for event in events:
    if icd10.exists(event):
            event_code = icd10.find(event)
            event_descrs.append(event_code.description)
            try:
                event_chapters.append(event_code.chapter)
                event_block_descrs.append(event_code.block_description)
            except:
                event_chapters.append(None); event_block_descrs.append(None);
    else:
        event_descrs.append(None); event_chapters.append(None); event_block_descrs.append(None);
event_descr_df = pd.DataFrame({'event' : events, 'event_descr' : event_descrs, 'event_chapter' : event_chapters, 'event_block_description' : event_block_descrs})

# %%
risk_cols = ['text_risk_score', 'stage_risk_score', 'treatment_risk_score', 'prs_risk_score', 'somatic_risk_score']

dfs_to_append = []
cindex_rows = []
failed_events = {}

for event in tqdm(events):
    # --- read ---
    try:
        event_risk_profile = pd.read_csv(os.path.join(HELD_OUT_PATH, f'{event}_held_out_preds.csv'))
    except Exception as e:
        failed_events[event] = f"read error: {e}"
        continue

    try:
        # --- merge + filter ---
        event_pred_df = (
            event_risk_profile
            .merge(tte_df[['DFCI_MRN', event, f'tt_{event}']], on='DFCI_MRN', how='inner')
            .drop(columns=['DFCI_MRN'])
        )
        event_pred_df = event_pred_df.loc[event_pred_df[f'tt_{event}'] > 0].copy()

        # ====== c-index for RAW risk scores (univariate) ======
        # NOTE: lifelines concordance_index expects "higher score => longer survival"
        # If your risk_score means "higher risk => earlier event", use -score.
        T = event_pred_df[f'tt_{event}'].to_numpy()
        E = event_pred_df[event].to_numpy().astype(int)

        for col in risk_cols:
            s = event_pred_df[col].to_numpy()

            ok = np.isfinite(T) & np.isfinite(s) & np.isfinite(E)
            if ok.sum() < 5:
                cidx = np.nan
            else:
                cidx = concordance_index(T[ok], -s[ok], E[ok])  # negate because higher risk => shorter time

            cindex_rows.append({
                "event": event,
                "covariate": col,
                "c_index_raw": cidx,
                "n": int(ok.sum())
            })

        # ====== your existing Cox betas (on standardized cols) ======
        event_pred_df[risk_cols] = StandardScaler().fit_transform(event_pred_df[risk_cols])

        event_model = CoxPHFitter().fit(event_pred_df, duration_col=f'tt_{event}', event_col=event)

        event_model_results = (
            event_model.summary
            .reset_index()[['covariate', 'coef', 'exp(coef)', 'p']]
            .copy()
        )

        # If you *really* want to collapse names like you did, keep this,
        # but it would turn all 5 into "text/stage/..." only if they have suffixes.
        event_model_results['covariate'] = event_model_results['covariate'].apply(lambda x: x.split('_')[0])
        event_model_results['event'] = event

        dfs_to_append.append(event_model_results)

        # ====== optional: multivariable c-index for the fitted Cox model ======
        # Predicted partial hazard: higher => higher risk (shorter time), so negate for concordance_index
        ph = event_model.predict_partial_hazard(event_pred_df).to_numpy().ravel()
        ok2 = np.isfinite(T) & np.isfinite(ph) & np.isfinite(E)
        cindex_rows.append({
            "event": event,
            "covariate": "cox_all_5",
            "c_index_raw": concordance_index(T[ok2], -ph[ok2], E[ok2]),
            "n": int(ok2.sum())
        })

    except Exception as e:
        failed_events[event] = f"model fit error: {e}"
        continue

betas_df = pd.concat(dfs_to_append, ignore_index=True) if dfs_to_append else pd.DataFrame()
cindex_df = pd.DataFrame(cindex_rows)
# Out:
#   1%|          | 4/338 [00:00<01:16,  4.39it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1679: RuntimeWarning: overflow encountered in exp
#   scores = weights * exp(dot(X, beta))
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1700: RuntimeWarning: invalid value encountered in add
#   risk_phi_x = risk_phi_x + phi_x_i
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1701: RuntimeWarning: invalid value encountered in add
#   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1733: RuntimeWarning: invalid value encountered in multiply
#   a1 = risk_phi_x_x * denom
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1735: RuntimeWarning: invalid value encountered in multiply
#   summand = numer * denom[:, None]
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1740: RuntimeWarning: divide by zero encountered in log
#   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
#   4%|▍         | 15/338 [00:03<01:06,  4.87it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.76749e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.43116e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#   5%|▌         | 18/338 [00:04<01:13,  4.38it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.13775e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=8.31297e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.03915e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#   6%|▌         | 21/338 [00:04<01:11,  4.43it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#   8%|▊         | 28/338 [00:06<01:24,  3.67it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#   9%|▉         | 31/338 [00:07<01:15,  4.07it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  10%|█         | 34/338 [00:08<01:23,  3.63it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.02054e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  11%|█         | 38/338 [00:09<01:18,  3.82it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  12%|█▏        | 41/338 [00:09<01:14,  4.01it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.37709e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.67621e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  14%|█▍        | 47/338 [00:11<01:14,  3.92it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  14%|█▍        | 49/338 [00:11<01:17,  3.71it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.35067e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  17%|█▋        | 58/338 [00:14<01:05,  4.29it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.09132e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  19%|█▊        | 63/338 [00:15<01:09,  3.94it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  28%|██▊       | 96/338 [00:22<00:59,  4.10it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  30%|███       | 103/338 [00:24<00:45,  5.14it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  31%|███▏      | 106/338 [00:25<00:53,  4.34it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  34%|███▍      | 115/338 [00:27<00:34,  6.47it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.39125e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.95071e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.46054e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  34%|███▍      | 116/338 [00:27<00:39,  5.64it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.44899e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.96822e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.04678e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1607: ConvergenceWarning: Newton-Raphson convergence completed successfully but norm(delta) is still high, 0.146. This may imply non-unique solutions to the maximum likelihood. Perhaps there is collinearity or complete separation in the dataset?
#
#   warnings.warn(
#  35%|███▌      | 119/338 [00:28<00:53,  4.06it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  36%|███▌      | 120/338 [00:28<01:05,  3.34it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.17346e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  39%|███▉      | 131/338 [00:30<00:42,  4.92it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  40%|███▉      | 134/338 [00:31<00:53,  3.84it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.05408e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.95665e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  43%|████▎     | 145/338 [00:34<00:42,  4.57it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.07632e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  47%|████▋     | 159/338 [00:37<00:37,  4.71it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  53%|█████▎    | 178/338 [00:42<00:38,  4.20it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=6.42109e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  53%|█████▎    | 179/338 [00:42<00:34,  4.62it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.78462e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  53%|█████▎    | 180/338 [00:42<00:30,  5.11it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.51169e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  55%|█████▍    | 185/338 [00:43<00:35,  4.35it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.1907e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  61%|██████    | 207/338 [00:48<00:33,  3.96it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.00533e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.19832e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  62%|██████▏   | 208/338 [00:48<00:31,  4.10it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.41703e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  64%|██████▎   | 215/338 [00:50<00:22,  5.53it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.72848e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.52906e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  64%|██████▍   | 216/338 [00:50<00:22,  5.32it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  65%|██████▌   | 221/338 [00:51<00:21,  5.55it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  66%|██████▋   | 224/338 [00:51<00:24,  4.61it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=7.74593e-18): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  67%|██████▋   | 228/338 [00:52<00:23,  4.67it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  69%|██████▊   | 232/338 [00:53<00:23,  4.55it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  70%|██████▉   | 236/338 [00:54<00:23,  4.28it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=3.26895e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  70%|███████   | 237/338 [00:54<00:21,  4.69it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  70%|███████   | 238/338 [00:55<00:22,  4.40it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  71%|███████   | 240/338 [00:55<00:25,  3.86it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.12364e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  75%|███████▌  | 254/338 [00:58<00:19,  4.21it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/utils/__init__.py:1120: ConvergenceWarning: Column stage_risk_score have very low variance when conditioned on death event present or not. This may harm convergence. This could be a form of 'complete separation'. For example, try the following code:
#
# >>> events = df['I65'].astype(bool)
# >>> print(df.loc[events, 'stage_risk_score'].var())
# >>> print(df.loc[~events, 'stage_risk_score'].var())
#
# A very low variance means that the column stage_risk_score completely determines whether a subject dies or not. See https://stats.stackexchange.com/questions/11109/how-to-deal-with-perfect-separation-in-logistic-regression.
#
#   warnings.warn(dedent(warning_text), ConvergenceWarning)
#  79%|███████▉  | 267/338 [01:01<00:13,  5.07it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.4229e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  81%|████████▏ | 275/338 [01:03<00:12,  4.90it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  84%|████████▎ | 283/338 [01:05<00:11,  4.72it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1679: RuntimeWarning: overflow encountered in exp
#   scores = weights * exp(dot(X, beta))
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1700: RuntimeWarning: invalid value encountered in add
#   risk_phi_x = risk_phi_x + phi_x_i
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1701: RuntimeWarning: invalid value encountered in add
#   risk_phi_x_x = risk_phi_x_x + phi_x_x_i
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1733: RuntimeWarning: invalid value encountered in multiply
#   a1 = risk_phi_x_x * denom
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1735: RuntimeWarning: invalid value encountered in multiply
#   summand = numer * denom[:, None]
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1740: RuntimeWarning: divide by zero encountered in log
#   log_lik = log_lik + dot(x_death_sum, beta) + weighted_average * log(denom).sum()
#  85%|████████▍ | 287/338 [01:05<00:08,  5.67it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  85%|████████▌ | 288/338 [01:06<00:11,  4.28it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.63222e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  86%|████████▌ | 290/338 [01:06<00:11,  4.18it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=4.57559e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  87%|████████▋ | 293/338 [01:07<00:10,  4.46it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  91%|█████████▏| 309/338 [01:11<00:07,  4.14it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=5.58068e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  95%|█████████▍| 320/338 [01:13<00:04,  4.09it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  96%|█████████▌| 324/338 [01:14<00:03,  4.01it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.31419e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
#  96%|█████████▌| 325/338 [01:14<00:02,  4.42it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  98%|█████████▊| 330/338 [01:16<00:01,  5.06it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/lifelines/fitters/coxph_fitter.py:1614: ConvergenceWarning: Newton-Raphson failed to converge sufficiently. Please see the following tips in the lifelines documentation: https://lifelines.readthedocs.io/en/latest/Examples.html#problems-with-convergence-in-the-cox-proportional-hazard-model
#   warnings.warn(
#  99%|█████████▉| 335/338 [01:17<00:00,  4.30it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.35401e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# 100%|█████████▉| 337/338 [01:17<00:00,  3.85it/s]/data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.43512e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=2.29207e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# /data/gusev/USERS/jpconnor/conda/envs/clinical_notes_project/lib/python3.13/site-packages/scipy/_lib/_util.py:1233: LinAlgWarning: Ill-conditioned matrix (rcond=1.50916e-17): result may not be accurate.
#   return f(*arrays, *other_args, **kwargs)
# 100%|██████████| 338/338 [01:18<00:00,  4.32it/s]

# %% [markdown]
# ## Summary Stats

# %%
betas_df['sig'] = betas_df['p'] < 0.05

# %%
len(betas_df['event'].unique())
# Out:
# 243

# %%
betas_df.loc[betas_df['sig'], 'covariate'].value_counts()
# Out:
# covariate
# text         116
# stage         71
# treatment     59
# prs           54
# somatic       44
# Name: count, dtype: int64

# %%
sig_events = betas_df.loc[betas_df['sig'], 'event'].unique()
len(sig_events)
# Out:
# 176

# %%
sig_preds_by_event = (betas_df.loc[betas_df['sig']]
                      .groupby('event')['sig'].sum().reset_index()).rename(columns={'sig' : 'num_sig_preds'})
sig_preds_by_event['num_sig_preds'].value_counts()
# Out:
# num_sig_preds
# 1    80
# 2    49
# 4    23
# 3    23
# 5     1
# Name: count, dtype: int64

# %%
sig_preds_by_event.loc[sig_preds_by_event['num_sig_preds'] == 5]
# Out:
#     event  num_sig_preds
# 143   R41              5

# %% [markdown]
# ## Performance Plots

# %%
cindex_df['covariate'] = cindex_df['covariate'].map({'text_risk_score' : 'text', 'stage_risk_score' : 'stage', 'treatment_risk_score' : 'treatment', 
                                                     'prs_risk_score' : 'prs', 'somatic_risk_score' : 'somatic', 'cox_all_5' : 'CoxPH w/ all features'})

# %%
cindex_df_filt = (
    cindex_df
    .assign(
        mu=cindex_df.groupby("covariate")["c_index_raw"].transform("mean"),
        sd=cindex_df.groupby("covariate")["c_index_raw"].transform("std"),
    )
    .loc[lambda d: (d["c_index_raw"] >= d["mu"] - 3*d["sd"]) &
                    (d["c_index_raw"] <= d["mu"] + 3*d["sd"])]
    .drop(columns=["mu", "sd"])
)

# %%
order = (cindex_df_filt.groupby('covariate')['c_index_raw'].mean().sort_values(ascending=False).index.tolist())

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

plt.figure(figsize=(14, 8))
ax = sns.violinplot(
    data=cindex_df_filt,
    x="covariate",
    y="c_index_raw",
    order=order,
    inner="quartile",
    cut=0,
    scale="width"
)

ax.set_xlabel("")
ax.set_ylabel("c-index using feature class risk score")
plt.axhline(0.5, color="black", linewidth=1)
# plt.xticks(rotation=45, ha="right")
plt.title("Distribution of C-indices by Covariate")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1641843/1433175005.py:7: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
#   ax = sns.violinplot(

# %%
cindex_df_w_descr = cindex_df.merge(event_descr_df, on='event')
for covar in cindex_df_w_descr['covariate'].unique():
    cov_cindex_df = cindex_df_w_descr.loc[cindex_df_w_descr['covariate'] == covar].sort_values(by='c_index_raw', ascending=False).iloc[0:5]
    print(covar)
    for index, row in cov_cindex_df.iterrows():
        print(f'Event = {row['event_descr']}')
        # print(f'C-index = {row['c_index_raw'] : 0.3f}')
# Out:
# text
# Event = Cytomegaloviral disease
# Event = Ovarian dysfunction
# Event = Benign prostatic hyperplasia
# Event = Immunodeficiency with predominantly antibody defects
# Event = Noninflammatory disorders of ovary, fallopian tube and broad ligament
# stage
# Event = Ovarian dysfunction
# Event = Benign prostatic hyperplasia
# Event = Noninflammatory disorders of ovary, fallopian tube and broad ligament
# Event = Male erectile dysfunction
# Event = Inguinal hernia
# treatment
# Event = Ovarian dysfunction
# Event = Benign prostatic hyperplasia
# Event = Noninflammatory disorders of ovary, fallopian tube and broad ligament
# Event = Male erectile dysfunction
# Event = Other chronic obstructive pulmonary disease
# prs
# Event = Benign prostatic hyperplasia
# Event = Inguinal hernia
# Event = Hypofunction and other disorders of the pituitary gland
# Event = Male erectile dysfunction
# Event = Other chronic obstructive pulmonary disease
# somatic
# Event = Benign prostatic hyperplasia
# Event = Inguinal hernia
# Event = Other chronic obstructive pulmonary disease
# Event = Other noninflammatory disorders of vagina
# Event = Respiratory conditions due to other external agents
# CoxPH w/ all features
# Event = Noninflammatory disorders of ovary, fallopian tube and broad ligament
# Event = Diabetes mellitus due to underlying condition
# Event = Other chronic obstructive pulmonary disease
# Event = Pain and other conditions associated with female genital organs and menstrual cycle
# Event = Hypofunction and other disorders of the pituitary gland

# %%
pd.set_option("display.max_colwidth", None)

(cindex_df.assign(delta=lambda x: x.c_index_raw - x.groupby("event").c_index_raw.transform("mean"))
    .sort_values("delta", ascending=False)
    .groupby("covariate")
    .head(3)).merge(event_descr_df, on='event')[['event', 'event_descr', 'covariate', 'c_index_raw', 'delta']].sort_values(by=['covariate', 'c_index_raw'], ascending=[True, False]).round(3)
# Out:
#    event  \
# 0    E08
# 1    G31
# 4    R61
# 6    N50
# 7    R65
# 8    E08
# 13   M84
# 12   H11
# 17   D59
# 11   E28
# 9    R32
# 15   I44
# 2    B25
# 3    E08
# 5    K86
# 10   E28
# 14   I77
# 16   I44
#
#                                                                             event_descr  \
# 0                                         Diabetes mellitus due to underlying condition
# 1               Other degenerative diseases of nervous system, not elsewhere classified
# 4                                                             Generalized hyperhidrosis
# 6                                Other and unspecified disorders of male genital organs
# 7   Symptoms and signs specifically associated with systemic inflammation and infection
# 8                                         Diabetes mellitus due to underlying condition
# 13                                                       Disorder of continuity of bone
# 12                                                       Other disorders of conjunctiva
# 17                                                            Acquired hemolytic anemia
# 11                                                                  Ovarian dysfunction
# 9                                                      Unspecified urinary incontinence
# 15                                        Atrioventricular and left bundle-branch block
# 2                                                               Cytomegaloviral disease
# 3                                         Diabetes mellitus due to underlying condition
# 5                                                            Other diseases of pancreas
# 10                                                                  Ovarian dysfunction
# 14                                           Other disorders of arteries and arterioles
# 16                                        Atrioventricular and left bundle-branch block
#
#                 covariate  c_index_raw  delta
# 0   CoxPH w/ all features        0.813  0.257
# 1   CoxPH w/ all features        0.675  0.230
# 4   CoxPH w/ all features        0.671  0.185
# 6                     prs        0.752  0.147
# 7                     prs        0.697  0.126
# 8                     prs        0.661  0.105
# 13                somatic        0.651  0.066
# 12                somatic        0.585  0.068
# 17                somatic        0.546  0.056
# 11                  stage        0.870  0.075
# 9                   stage        0.693  0.076
# 15                  stage        0.623  0.060
# 2                    text        0.951  0.216
# 3                    text        0.746  0.190
# 5                    text        0.721  0.158
# 10              treatment        0.870  0.075
# 14              treatment        0.726  0.061
# 16              treatment        0.623  0.060

# %%
# extreme_events = ['D62', 'H11', 'R26', 'E23', 'D49']
# violin_plot_order = ["stage", "text", "treatment", "prs", "somatic"]

# sig_results_only = betas_df.loc[betas_df['event'].isin(set(sig_events) - set(extreme_events))]

# sig_results_only_filt = (
#     sig_results_only
#     .assign(
#         mu=sig_results_only.groupby("covariate")["coef"].transform("mean"),
#         sd=sig_results_only.groupby("covariate")["coef"].transform("std"),
#     )
#     .loc[lambda d: (d["coef"] >= d["mu"] - 3*d["sd"]) &
#                     (d["coef"] <= d["mu"] + 3*d["sd"])]
#     .drop(columns=["mu", "sd"])
# )
# order = (sig_results_only_filt.groupby('covariate')['coef'].mean().sort_values(ascending=False).index.tolist())

# sns.set(style="whitegrid")

# plt.figure(figsize=(14, 8))
# ax = sns.violinplot(
#     data=sig_results_only_filt,
#     order=order,
#     x="covariate",
#     y="coef",
#     inner="quartile",
#     cut=0,
#     scale="width"
# )

# ax.set_xlabel("")
# ax.set_ylabel("log HRs")

# plt.axhline(0, color="black", linewidth=1)
# plt.title("Distribution of Log HRs by Covariate (Significant events, all features)")
# plt.tight_layout()
# plt.show()

# %%
# extreme_events = ['D62', 'H11', 'R26', 'E23', 'D49']

# sig_features_only = betas_df.loc[betas_df['sig']]

# sns.set(style="whitegrid")

# plt.figure(figsize=(14, 8))
# ax = sns.violinplot(
#     data=sig_features_only,
#     order=violin_plot_order,
#     x="covariate",
#     y="coef",
#     inner="quartile",
#     cut=0,
#     scale="width"
# )

# ax.set_xlabel("")
# ax.set_ylabel("log HRs")

# plt.axhline(0, color="black", linewidth=1)
# plt.title("Distribution of Log HRs by Covariate (Significant event, feature combinations only)")
# plt.tight_layout()
# plt.show()

# %%
events_to_include = cindex_df.groupby('event')['c_index_raw'].mean().reset_index().sort_values(by='c_index_raw', ascending=False).iloc[0:50]['event'].tolist()

# %%
events_to_include = sig_results_only_filt.merge(cindex_df, on='event').groupby('event')['c_index_raw'].mean().reset_index().sort_values(by='c_index_raw', ascending=False).iloc[0:50]['event'].tolist()

# %%
sig_results_only_filt_w_descr = sig_results_only_filt.loc[sig_results_only_filt['event'].isin(events_to_include)].merge(event_descr_df[['event', 'event_descr']], on='event')

heatmap_df = (
    sig_results_only_filt_w_descr
    .pivot_table(
        index="event_descr",
        columns="covariate",
        values="coef",
        aggfunc="mean"   # or first / median if appropriate
    )
    .fillna(0.0)
)

sns.set(context="notebook", style="white")

g = sns.clustermap(
    heatmap_df,
    cmap="vlag",
    center=0,
    method="average",
    metric="euclidean",
    row_cluster=True,
    col_cluster=False,
    figsize=(18, 20),
    linewidths=0.25,
    cbar_kws={"label": "Log HR"},
    cbar_pos=(0.92, 0.15, 0.02, 0.55) 
)

# ---- Remove x-axis labels & ticks ----
# g.ax_heatmap.set_yticks([])
# g.ax_heatmap.set_ylabel("")

# Optional: also remove the column dendrogram axis (since col_cluster=False)
if g.ax_col_dendrogram is not None:
    g.ax_col_dendrogram.set_visible(False)

# Optional: clean y-axis label
g.ax_heatmap.set_xlabel("Feature Class")
# Title + spacing
g.fig.suptitle(
    "Heatmap of Log HRs across Significant Events",
    x=0.5, y=0.97, ha="center", fontsize=16
)
g.fig.subplots_adjust(top=0.92)

# --- HARD align colorbar to heatmap bounds ---
# hm_pos = g.ax_heatmap.get_position()  # Bbox in figure coords

# pad = 0.01          # gap between heatmap and colorbar
# cbar_w = 0.02       # colorbar width

# # Place cbar just to the right of the heatmap, matching heatmap height
# g.cax.set_position([hm_pos.x1 + pad, hm_pos.y0, cbar_w, hm_pos.height])

# # Put ticks/label on the right side of the colorbar
# g.cax.yaxis.set_ticks_position("right")
# g.cax.yaxis.set_label_position("right")

# Pull plot up toward the title
# g.fig.subplots_adjust(top=0.92)
plt.show()

# %%
events_to_include = cindex_df.groupby('event')['c_index_raw'].mean().reset_index().sort_values(by='c_index_raw', ascending=False).iloc[0:50]['event'].tolist()
cindex_df_w_descr = cindex_df.loc[(cindex_df['event'].isin(events_to_include)) &
                                  (cindex_df['covariate'] != 'CoxPH w/ all features')].merge(event_descr_df[['event', 'event_descr']], on='event').dropna()

heatmap_df = (
    cindex_df_w_descr
    .pivot_table(
        index="event_descr",
        columns="covariate",
        values="c_index_raw",
        aggfunc="mean"   # or first / median if appropriate
    )
    .fillna(0.0)
)

# --- scale columns (z-score) ---
heatmap_scaled = heatmap_df.apply(
    lambda s: (s - s.mean()) / s.std(ddof=0),
    axis=1
).fillna(0.0)  # handles columns with 0 variance -> NaN


sns.set(context="notebook", style="white")

g = sns.clustermap(
    heatmap_scaled,
    cmap="vlag",
    center=0,
    method="average",
    metric="euclidean",
    row_cluster=True,
    col_cluster=False,
    figsize=(14, 14),
    linewidths=0.25,
    cbar_kws={"label": "C-Index"},
    cbar_pos=(0.92, 0.15, 0.02, 0.55) 
)

# ---- Remove x-axis labels & ticks ----
# g.ax_heatmap.set_yticks([])
# g.ax_heatmap.set_ylabel("")

# Optional: also remove the column dendrogram axis (since col_cluster=False)
if g.ax_col_dendrogram is not None:
    g.ax_col_dendrogram.set_visible(False)

# Optional: clean y-axis label
g.ax_heatmap.set_xlabel("Feature Class")
# Title + spacing
g.fig.suptitle(
    "Heatmap of Log HRs across Significant Events",
    x=0.5, y=0.97, ha="center", fontsize=16
)
g.fig.subplots_adjust(top=0.92)

# --- HARD align colorbar to heatmap bounds ---
g.fig.canvas.draw()

hm_pos = g.ax_heatmap.get_position()

pad = 0.015   # increase padding
cbar_w = 0.02

g.cax.set_position([
    hm_pos.x1 + pad,
    hm_pos.y0,
    cbar_w,
    hm_pos.height
])
g.cax.set_position([hm_pos.x1 + pad, hm_pos.y0, cbar_w, hm_pos.height])

# # Put ticks/label on the right side of the colorbar
# g.cax.yaxis.set_ticks_position("right")
# g.cax.yaxis.set_label_position("right")

# Pull plot up toward the title
# g.fig.subplots_adjust(top=0.92)
plt.show()

# %%
covariate_cols = ["prs", "somatic", "stage", "text", "treatment"]

X = heatmap_df[covariate_cols]

corr = X.corr(method="pearson")  # or "spearman"
mask = np.eye(corr.shape[0], dtype=bool)

plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr,
    mask=mask,
    cmap="vlag",
    center=0,
    linewidths=0.25,
    cbar_kws={"label": "Pearson R"}
)

ax.set_xlabel("")
ax.set_ylabel("")

plt.title("Covariate Correlation Map (Across all event, log HRs)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Comparing when both covariates are significant

# %%
sig_cov_only = sig_results_only.loc[sig_results_only['p'] < 0.05]

beta_sig_wide = (
    sig_cov_only
    .pivot(index="event", columns="covariate", values="coef")
)

# %%
covariates = beta_sig_wide.columns.tolist()

# %%
corr_sig_only = beta_sig_wide.corr(method="pearson")
mask = np.eye(corr.shape[0], dtype=bool)

plt.figure(figsize=(10, 8))
ax = sns.heatmap(
    corr_sig_only,
    mask=mask,
    cmap="vlag",
    center=0,
    linewidths=0.25,
    cbar_kws={"label": "Correlation"}
)

ax.set_xlabel("")
ax.set_ylabel("")

plt.title("Covariate Correlation Map (Restricting to only significant log HRs)")
plt.tight_layout()
plt.show()
