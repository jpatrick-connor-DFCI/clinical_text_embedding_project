# %%
import os
import pandas as pd

# Paths
DATA_PATH = '/data/gusev/USERS/jpconnor/data/clinical_text_embedding_project/'
MARKER_PATH = os.path.join(DATA_PATH, 'biomarker_analysis/')
PROFILE_PATH = '/data/gusev/PROFILE/CLINICAL/'

# %%
idmap = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2024_idmap.csv'))

amp_2024_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2024.ALL_AMP_CARRIERS.csv'), index_col=0)
cnv_2024_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2024.ALL_CNV_CARRIERS.csv'), index_col=0)
del_2024_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2024.ALL_DEL_CARRIERS.csv'), index_col=0)
snv_2024_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2024.MUTATION_CARRIERS.csv'), index_col=0)

amp_2022_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2022.ALL_AMP_CARRIERS.csv'), index_col=0)
cnv_2022_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2022.ALL_CNV_CARRIERS.csv'), index_col=0)
del_2022_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2022.ALL_DEL_CARRIERS.csv'), index_col=0)
snv_2022_data = pd.read_csv(os.path.join(PROFILE_PATH, 'PROFILE_2022.MUTATION_CARRIERS.csv'), index_col=0)
