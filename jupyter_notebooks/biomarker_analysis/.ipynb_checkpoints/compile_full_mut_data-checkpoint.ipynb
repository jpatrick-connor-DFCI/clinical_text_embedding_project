# %%
import os
import warnings
import random
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Paths
PROJ_PATH = '/data/gusev/USERS/jpconnor/clinical_text_project/'
DATA_PATH = os.path.join(PROJ_PATH, 'data/')
NOTES_PATH = os.path.join(DATA_PATH, 'batched_datasets/processed_datasets/')
MARKER_PATH = os.path.join(DATA_PATH, 'biomarker_analysis/')
IPTW_RESULTS_PATH = os.path.join(MARKER_PATH, 'IPTW_runs/')
PROFILE_PATH = '/data/gusev/PROFILE/CLINICAL/'
OncDRS_PATH = os.path.join(PROFILE_PATH, 'OncDRS/ALL_2025_03/')

# %%
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.ALL_AMP_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.ALL_CNV_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.ALL_DEL_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.DEEP_AMP_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.DEEP_DEL_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.MUTATION_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.TIER_1_MUTATION_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.TIER_2_MUTATION_CARRIERS.csv
# /data/gusev/PROFILE/CLINICAL/PROFILE_2024.TIER_3_MUTATION_CARRIERS.csv
# Out:
# ['CLINICAL',
#  'EUR.UNREL.PROFILE_COMB.HQ.pruned.PCA.eigenvec',
#  'PBP_CT_PANEL_MS_STATUS.csv',
#  'PROFILE_2024_ANCESTRY.NON_EUR.all.id',
#  'PROFILE_2024_ANCESTRY.csv.gz',
#  'PROFILE_2024_ANCESTRY.pdf',
#  '.ipynb_checkpoints',
#  'ASHKENAZI',
#  'BRCA',
#  'CANCER_TYPE',
#  'CBIO_ONCDRS_selected',
#  'COLITIS',
#  'DIAGNOSES',
#  'EXPOSURE',
#  'IP',
#  'LONGITUDINAL_OUTCOMES',
#  'LUNG',
#  'LYNCH_SYNDROME',
#  'MELANOMA',
#  'NOTEBOOKS',
#  'NOTES',
#  'OncDRS',
#  'PFS',
#  'PROFILE_2024_error',
#  'PROGRESSION_PREDICTION',
#  'PRS',
#  'Projects',
#  'RESPONSE',
#  'RHP_SOLID',
#  'analysis',
#  'data',
#  'eugene_cohort',
#  'irAE',
#  'onconpc',
#  'pgsc_calc',
#  'profile_medications',
#  'robust_VTE_pred_project',
#  'robust_VTE_pred_project_2025_03_cohort',
#  'smoking_signature',
#  '.CANCER_TYPE.csv.swp',
#  '._OS_ALL.PBP_duplicate4Viewing_ignore.csv',
#  '.~lock.OS_ALL.PBP.csv#',
#  '.~lock.OS_ALL.csv#',
#  '2020_2022_BL_PBP.tab',
#  'ALL_PRS.csv',
#  'ANCESTRY.R',
#  'ANCESTRY.tab',
#  'BLNUM_CT.csv',
#  'BLNUM_CT_PANEL.csv',
#  'BLNUM_MRN_PBP.tab',
#  'BLNUM_testtype.csv',
#  'BMI.csv',
#  'BPB_CBIO.tab',
#  'CANCER_TYPE.csv',
#  'CBIO_DIAGNOSIS.tab',
#  'CBIO_PANEL_VERSION.csv',
#  'DFCI_BWH_MRN.tab',
#  'EHR_DEPARTMENT.csv',
#  'EUR.PROFILE_COMB.HQ.pruned.unrel.keep',
#  'EUR.UNREL.PROFILE_COMB.HQ.MRN',
#  'IO_LUNG_HLA.csv.gz',
#  'IO_MRN.csv',
#  'IO_MRN_ANC.tab',
#  'IO_START.R',
#  'IO_START2024.IMPUTED.csv',
#  'IO_START2024.csv',
#  'MRN_ANCESTRY.tab',
#  'MRN_MAP.R',
#  'OS_ALL.PBP.README',
#  'OS_ALL.PBP.csv',
#  'OS_ALL.PBP.sh',
#  'OS_ALL.PBP_duplicate4Viewing_ignore.csv',
#  'OS_ALL.csv',
#  'PRCA_MOUNT.tab',
#  'PROFILE_2022.ALL_AMP_CARRIERS.csv',
#  'PROFILE_2022.ALL_AMP_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.ALL_CNV_CARRIERS.csv',
#  'PROFILE_2022.ALL_DEL_CARRIERS.csv',
#  'PROFILE_2022.ALL_DEL_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.ANYTHING_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.CNV_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.DEEP_AMP_CARRIERS.csv',
#  'PROFILE_2022.DEEP_AMP_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.DEEP_DEL_CARRIERS.csv',
#  'PROFILE_2022.DEEP_DEL_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.MUTATION_CARRIERS.csv',
#  'PROFILE_2022.MUTATION_CARRIERS_BY_BIOPSY.csv',
#  'PROFILE_2022.TIER_1_MUTATION_CARRIERS.csv',
#  'PROFILE_2022.TIER_2_MUTATION_CARRIERS.csv',
#  'PROFILE_2022.TIER_3_MUTATION_CARRIERS.csv',
#  'PROFILE_2022.dup',
#  'PROFILE_2022.dup.nonuniq',
#  'PROFILE_2022.dup.uniq',
#  'PROFILE_2022_ANCESTRY.NON_EUR.all.id',
#  'PROFILE_2022_ANCESTRY.NON_EUR.new.id',
#  'PROFILE_2022_ANCESTRY.csv.gz',
#  'PROFILE_2022_ANCESTRY_BLNUM.csv.gz',
#  'PROFILE_2022_NEW_MRN.id',
#  'PROFILE_2024.ALL_AMP_CARRIERS.csv',
#  'PROFILE_2024.ALL_CNV_CARRIERS.csv',
#  'PROFILE_2024.ALL_DEL_CARRIERS.csv',
#  'PROFILE_2024.DEEP_AMP_CARRIERS.csv',
#  'PROFILE_2024.DEEP_DEL_CARRIERS.csv',
#  'PROFILE_2024.DFCI_BWH_MRN.tab',
#  'PROFILE_2024.MUTATION_CARRIERS.csv',
#  'PROFILE_2024.TIER_1_MUTATION_CARRIERS.csv',
#  'PROFILE_2024.TIER_2_MUTATION_CARRIERS.csv',
#  'PROFILE_2024.TIER_3_MUTATION_CARRIERS.csv',
#  'PROFILE_2024_idmap.csv',
#  'PROFILE_MEL_MRN.tab',
#  'PROFILE_MRN_BL_PANEL.PBP.tab',
#  'RAPIDHEME_AND_ONCOPANEL.csv',
#  'RESTRICTED.csv',
#  'TREATMENT_DEPARTMENT.csv',
#  'Untitled.ipynb',
#  'Untitled1.ipynb',
#  'Untitled2.ipynb',
#  'allIO2024filtered.csv',
#  'ancestry.pdf',
#  'ancestry_bars.pdf',
#  'bloodpressure.csv',
#  'cancer_types.pdf',
#  'clinical.sql',
#  'demographics.csv',
#  'dup.sh',
#  'hispanic.R',
#  'hispanic.pbp',
#  'ids.mor.tab',
#  'mapar',
#  'sample_id_to_cbio.txt',
#  'total_CNV_per_gene.csv',
#  'PROFILE_2024_idmap.MRN.id.gz']
