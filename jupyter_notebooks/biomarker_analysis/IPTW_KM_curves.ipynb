# %%
import os
import warnings
import random
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from lifelines import KaplanMeierFitter
from lifelines.statistics import logrank_test
from lifelines.exceptions import StatisticalWarning

random.seed(42)  # set seed for reproducibility


def compute_common_support_and_iptw(df, ps_col="ICI_prediction", treat_col="PX_on_ICI",
                                   trim_common_support=True, trunc_pct=(1, 99), eps=1e-6):
    """
    Mirrors your logic:
      - optional common support trimming on propensity
      - stabilized ATE IPTW
      - truncation at given percentiles
    Returns: df copy with 'IPTW' column.
    """
    out = df.copy()

    ps_raw = out[ps_col].clip(eps, 1 - eps)

    if trim_common_support:
        ps_t = ps_raw[out[treat_col] == 1]
        ps_c = ps_raw[out[treat_col] == 0]
        lower = max(ps_t.min(), ps_c.min())
        upper = min(ps_t.max(), ps_c.max())
        out = out[(ps_raw >= lower) & (ps_raw <= upper)].copy()
        ps_raw = out[ps_col].clip(eps, 1 - eps)

    p_treated = out[treat_col].mean()
    p_control = 1 - p_treated

    w = np.where(out[treat_col] == 1, p_treated / ps_raw, p_control / (1 - ps_raw))
    lo, hi = np.percentile(w, trunc_pct)
    out["IPTW"] = np.clip(w, lo, hi)

    return out


def combined_km_in_io_two_panel(df, marker, duration_col="tt_death", event_col="death",
                                treat_col="PX_on_ICI", weight_col="IPTW",
                                marker_pos_label="Marker+", marker_neg_label="Marker-",
                                title=None,
                                # adjusted (bootstrap) options
                                renormalize_weights=True, n_boot=250, grid_points=200, seed=42,
                                show_adjusted_ci=True, adjusted_ci_alpha=0.20,
                                show_adjusted_naive_line=False,
                                # unadjusted options
                                show_unadjusted_ci=True, unadjusted_ci_alpha=0.15,
                                show_unadjusted_naive_points=False,
                                savefig=False, output_path=None):
    """
    One PNG per marker with TWO PANELS (same figure):
      - Left: Adjusted (IPTW + bootstrap pointwise 95% CI) KM curves in ICI-treated cohort
      - Right: Unadjusted (standard KM + Greenwood CI) KM curves in ICI-treated cohort

    Curves are split by marker (0/1). All fits are within treat_col==1.

    Returns: fig, (ax_adj, ax_unadj), info_dict
    """
    d = df.loc[df[treat_col] == 1, [duration_col, event_col, marker, weight_col]].dropna().copy()
    d_pos = d[d[marker] == 1].copy()
    d_neg = d[d[marker] == 0].copy()

    # p-values
    lr_w = logrank_test(
        d_pos[duration_col], d_neg[duration_col],
        event_observed_A=d_pos[event_col],
        event_observed_B=d_neg[event_col],
        weights_A=d_pos[weight_col],
        weights_B=d_neg[weight_col],
    )
    lr_u = logrank_test(
        d_pos[duration_col], d_neg[duration_col],
        event_observed_A=d_pos[event_col],
        event_observed_B=d_neg[event_col],
    )

    # figure with two subplots
    fig, (ax_adj, ax_unadj) = plt.subplots(1, 2, figsize=(14, 5.5), sharey=True)

    # -------------------------
    # Unadjusted panel (right)
    # -------------------------
    km_u = KaplanMeierFitter()

    km_u.fit(
        d_pos[duration_col], d_pos[event_col],
        label=f"{marker_pos_label} (n={len(d_pos)})"
    )
    km_u.plot_survival_function(
        ax=ax_unadj, ci_show=show_unadjusted_ci, ci_alpha=unadjusted_ci_alpha, at_risk_counts=False
    )
    if show_unadjusted_naive_points:
        ax_unadj.scatter(
            km_u.survival_function_.index.values,
            km_u.survival_function_[km_u._label].values,
            s=8
        )

    km_u.fit(
        d_neg[duration_col], d_neg[event_col],
        label=f"{marker_neg_label} (n={len(d_neg)})"
    )
    km_u.plot_survival_function(
        ax=ax_unadj, ci_show=show_unadjusted_ci, ci_alpha=unadjusted_ci_alpha, at_risk_counts=False
    )
    if show_unadjusted_naive_points:
        ax_unadj.scatter(
            km_u.survival_function_.index.values,
            km_u.survival_function_[km_u._label].values,
            s=8
        )

    ax_unadj.set_title(f"Unadjusted KM\nlog-rank p={lr_u.p_value:.3g}")
    ax_unadj.set_xlabel("Time")
    ax_unadj.legend()

    # -------------------------
    # Adjusted panel (left)
    # -------------------------
    if renormalize_weights:
        for sub in (d_pos, d_neg):
            s = sub[weight_col].sum()
            if s > 0:
                sub[weight_col] = sub[weight_col] * (len(sub) / s)

    tmax = float(np.nanmax(d[duration_col].values)) if len(d) else 0.0
    grid = np.linspace(0, tmax, grid_points) if tmax > 0 else np.array([0.0])

    def _bootstrap_group(df_g, seed_offset):
        rng = np.random.default_rng(seed + seed_offset)
        n = len(df_g)
        if n == 0:
            raise ValueError("Empty subgroup for bootstrap KM.")

        km = KaplanMeierFitter()

        # naive single-fit weighted curve (optional overlay)
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=StatisticalWarning)
            km.fit(df_g[duration_col], df_g[event_col], weights=df_g[weight_col])
            naive = km.survival_function_at_times(grid).values

        surv_mat = np.empty((n_boot, len(grid)), dtype=float)
        for b in range(n_boot):
            idx = rng.integers(0, n, size=n)
            bs = df_g.iloc[idx]
            with warnings.catch_warnings():
                warnings.filterwarnings("ignore", category=StatisticalWarning)
                km.fit(bs[duration_col], bs[event_col], weights=bs[weight_col])
            surv_mat[b, :] = km.survival_function_at_times(grid).values

        med = np.median(surv_mat, axis=0)
        lo = np.quantile(surv_mat, 0.025, axis=0)
        hi = np.quantile(surv_mat, 0.975, axis=0)
        return naive, med, lo, hi

    naive_pos, med_pos, lo_pos, hi_pos = _bootstrap_group(d_pos, seed_offset=1)
    naive_neg, med_neg, lo_neg, hi_neg = _bootstrap_group(d_neg, seed_offset=2)

    ax_adj.plot(grid, med_pos, linewidth=2, label=f"{marker_pos_label} (IPTW)")
    if show_adjusted_ci:
        ax_adj.fill_between(grid, lo_pos, hi_pos, alpha=adjusted_ci_alpha)

    ax_adj.plot(grid, med_neg, linewidth=2, label=f"{marker_neg_label} (IPTW)")
    if show_adjusted_ci:
        ax_adj.fill_between(grid, lo_neg, hi_neg, alpha=adjusted_ci_alpha)

    if show_adjusted_naive_line:
        ax_adj.plot(grid, naive_pos, linestyle=":", linewidth=1, label=f"{marker_pos_label} naive")
        ax_adj.plot(grid, naive_neg, linestyle=":", linewidth=1, label=f"{marker_neg_label} naive")

    ax_adj.set_title(f"IPTW-adjusted KM (bootstrap CI)\nweighted log-rank p={lr_w.p_value:.3g}")
    ax_adj.set_xlabel("Time")
    ax_adj.set_ylabel("Survival probability")
    ax_adj.legend()

    # overall title
    if title is None:
        title = f"{marker}: Adjusted vs Unadjusted KM (ICI cohort)"
    fig.suptitle(title, y=1.02)

    fig.tight_layout()

    if savefig and (output_path is not None):
        fig.savefig(output_path, bbox_inches="tight")
        plt.close(fig)

    info = {
        "marker": marker,
        "n_ici_pos": int(len(d_pos)),
        "n_ici_neg": int(len(d_neg)),
        "p_weighted_logrank": float(lr_w.p_value),
        "p_unweighted_logrank": float(lr_u.p_value),
        "n_boot": int(n_boot),
        "grid_points": int(grid_points),
    }
    return fig, (ax_adj, ax_unadj), info


# Paths
DATA_PATH = '/data/gusev/USERS/jpconnor/data/clinical_text_embedding_project/'
NOTES_PATH = os.path.join(DATA_PATH, 'batched_datasets/processed_datasets/')
MARKER_PATH = os.path.join(DATA_PATH, 'biomarker_analysis/')
FIGURE_PATH = '/data/gusev/USERS/jpconnor/figures/clinical_text_embedding_project/'
MARKER_FIG_PATH = os.path.join(FIGURE_PATH, 'biomarker_analysis/')
IPTW_FIG_PATH = os.path.join(MARKER_FIG_PATH, 'IPTW_figures/')
KM_FIG_PATH = os.path.join(IPTW_FIG_PATH, 'KM_curves/')

# %% [markdown]
# # Top / Notable Hits — IPTW vs Unweighted KM Curves
#
# **Track 1**: Two-panel (Overlap-weighted vs Unweighted) for ICI-only prognostic markers
# **Track 2**: Four-panel (ICI vs Non-ICI × Overlap-weighted vs Unweighted) for predictive interaction markers
#
# Selected schemes (based on literature validation of marker plausibility):
# - Track 1a: unweighted + OVL (generalizability weights excluded — inflated HRs on rare events)
# - Track 1b: prognostic-score-adjusted (unweighted only)
# - Track 2: noIPTW + OVL (ATE/ATT weights excluded — artifact-inflated results)

# %%
from sklearn.linear_model import LogisticRegression

# ── Configuration ─────────────────────────────────────────────────────
SPECS = [
    ("1to1", "embeddings_only"),
    ("1to1", "all_covariates"),
]
N_BOOT = 250
GRID_POINTS = 200
SEED = 42
MAX_TIME_DAYS = None  # set e.g. 1825 to cap at 5 years

# ── Output root ───────────────────────────────────────────────────────
OUT_ROOT = os.path.join(KM_FIG_PATH, "top_hits/")
os.makedirs(OUT_ROOT, exist_ok=True)

# ── Style ─────────────────────────────────────────────────────────────
plt.rcParams.update({
    "font.family": "sans-serif",
    "font.size": 11,
    "axes.titlesize": 13,
    "axes.labelsize": 12,
    "legend.fontsize": 10,
    "figure.dpi": 150,
    "savefig.dpi": 200,
    "savefig.bbox": "tight",
})

COLOR_POS = "#D62728"   # red for marker+
COLOR_NEG = "#1F77B4"   # blue for marker-
CI_ALPHA = 0.18

# ── Top / notable markers ────────────────────────────────────────────
# Curated from confounding-robust (Track 1) and cross-scheme robust (Track 2) results.
# Format: (marker, cancer_type)

TOP_TRACK1 = [
    # Confounding-robust (sig in both Track 1a and 1b) — pan-cancer
    ("ARID1A_SNV",     "pan_cancer"),
    ("BRAF_SNV",       "pan_cancer"),
    ("NOTCH1_SNV",     "pan_cancer"),
    ("PBRM1_SNV",      "pan_cancer"),
    ("SMC3_SNV",       "pan_cancer"),
    ("WHSC1_SNV",      "pan_cancer"),
    ("MLH1_SNV",       "pan_cancer"),
    ("FLT4_SNV",       "pan_cancer"),
    ("SF3B1_SNV",      "pan_cancer"),
    ("RNF43_SNV",      "pan_cancer"),
    ("KMT2A_SNV",      "pan_cancer"),
    ("CTCF_SNV",       "pan_cancer"),
    ("PIK3C2B_SNV",    "pan_cancer"),
    ("TFE3_SNV",       "pan_cancer"),
    ("IDH1_SNV",       "pan_cancer"),
    ("WHSC1L1_SNV",    "pan_cancer"),
    ("SETBP1_SNV",     "pan_cancer"),
    ("ARID2_SNV",      "pan_cancer"),
    # Tissue-specific confounding-robust
    ("INTRAGENIC_SV",  "LUNG"),
    ("NF1_DEL",        "SOFT_TISSUE"),
    ("SUZ12_DEL",      "SOFT_TISSUE"),
    ("ATM_DEL",        "SOFT_TISSUE"),
    ("USP28_DEL",      "SOFT_TISSUE"),
    ("EGFR_AMP",       "BRAIN"),
    ("GATA6_AMP",      "STOMACH"),
    ("RBBP8_AMP",      "STOMACH"),
]

TOP_TRACK2 = [
    # Cross-scheme robust (sig in both OVL and noIPTW)
    ("TP53_SNV",       "SOFT_TISSUE"),
    ("WHSC1_SNV",      "pan_cancer"),
    # Robust in multiple schemes (sig in ≥1, notable biology)
    ("CDK4_AMP",       "pan_cancer"),
    ("ERBB3_AMP",      "pan_cancer"),
    ("STAT6_AMP",      "pan_cancer"),
    ("GLI1_AMP",       "pan_cancer"),
    # OVL-only (primary scheme)
    ("KMT2D_AMP",      "pan_cancer"),
    ("ARID2_AMP",      "pan_cancer"),
    ("NOTCH2_DEL",     "BREAST"),
]

print(f"Specs to loop over: {len(SPECS)}")
for m, p in SPECS:
    print(f"  {m}_{p} -> IPTW_df_{m}_{p}.csv")
print(f"Track 1: {len(TOP_TRACK1)} markers x {len(SPECS)} specs = {len(TOP_TRACK1)*len(SPECS)} figures")
print(f"Track 2: {len(TOP_TRACK2)} markers x {len(SPECS)} specs = {len(TOP_TRACK2)*len(SPECS)} figures")

# %%
# ── Helper functions ──────────────────────────────────────────────────

COMMON_SUPPORT_PCT = (0.5, 99.5)
IPTW_TRUNC_PCT = (1, 99)
EPS = 1e-6


def recalibrate_propensity_within_subset(df, ps_col="ICI_prediction", treat_col="PX_on_ICI"):
    """Recalibrate propensity scores within a cancer-type subset."""
    ps = df[[ps_col]].values
    y = df[treat_col].values.astype(int)
    lr = LogisticRegression(penalty=None, solver="lbfgs", max_iter=1000)
    lr.fit(ps, y)
    return lr.predict_proba(ps)[:, 1]


def prepare_weighted_df(full_df, cancer_type):
    """Subset to cancer type, trim common support, compute OVL weights."""
    if cancer_type == "pan_cancer":
        df = full_df.copy()
    else:
        ct_col = f"CANCER_TYPE_{cancer_type}"
        if ct_col not in full_df.columns:
            raise ValueError(f"Column {ct_col} not found")
        df = full_df.loc[full_df[ct_col].astype(bool)].copy()
        if df["PX_on_ICI"].nunique() >= 2 and len(df) > 10:
            df["ICI_prediction"] = recalibrate_propensity_within_subset(df)

    ps_raw = df["ICI_prediction"].clip(EPS, 1 - EPS)
    ps_t = ps_raw[df["PX_on_ICI"] == 1]
    ps_c = ps_raw[df["PX_on_ICI"] == 0]

    lower = max(np.percentile(ps_t, COMMON_SUPPORT_PCT[0]),
                np.percentile(ps_c, COMMON_SUPPORT_PCT[0]))
    upper = min(np.percentile(ps_t, COMMON_SUPPORT_PCT[1]),
                np.percentile(ps_c, COMMON_SUPPORT_PCT[1]))
    df = df[(ps_raw >= lower) & (ps_raw <= upper)].copy()

    ps = df["ICI_prediction"].clip(EPS, 1 - EPS)
    treat = df["PX_on_ICI"]

    # Overlap weights (Track 2) — Li, Morgan & Zaslavsky (JASA 2018)
    # Targets equipoise population; no truncation needed (bounded 0-1)
    df["IPTW_OVL"] = np.where(treat == 1, 1 - ps, ps)

    # Overlap weights for ICI-only (Track 1): weight = 1 - ps
    ici_mask = treat == 1
    ici_ps = ps[ici_mask]
    df.loc[ici_mask, "IPTW_GEN_OVL"] = (1 - ici_ps).values

    return df


def bootstrap_weighted_km(durations, events, weights, grid,
                          n_boot=250, seed=42, renormalize=True):
    """Bootstrap weighted KM -> median, lo, hi survival curves on grid."""
    n = len(durations)
    if n == 0:
        return np.ones(len(grid)), np.ones(len(grid)), np.ones(len(grid))

    dur = durations.values if hasattr(durations, "values") else np.asarray(durations)
    evt = events.values if hasattr(events, "values") else np.asarray(events)
    wgt = weights.values if hasattr(weights, "values") else np.asarray(weights)

    if renormalize:
        s = wgt.sum()
        if s > 0:
            wgt = wgt * (n / s)

    rng = np.random.default_rng(seed)
    km = KaplanMeierFitter()
    surv_mat = np.empty((n_boot, len(grid)))

    for b in range(n_boot):
        idx = rng.integers(0, n, size=n)
        with warnings.catch_warnings():
            warnings.filterwarnings("ignore", category=StatisticalWarning)
            km.fit(dur[idx], evt[idx], weights=wgt[idx])
        surv_mat[b, :] = km.survival_function_at_times(grid).values

    return np.median(surv_mat, axis=0), np.quantile(surv_mat, 0.025, axis=0), np.quantile(surv_mat, 0.975, axis=0)


def unweighted_km(durations, events, grid):
    """Standard KM + Greenwood CI interpolated onto grid."""
    km = KaplanMeierFitter()
    km.fit(durations, events)
    surv = km.survival_function_at_times(grid).values
    ci = km.confidence_interval_survival_function_
    ci_lo = np.interp(grid, ci.index, ci.iloc[:, 0])
    ci_hi = np.interp(grid, ci.index, ci.iloc[:, 1])
    return surv, ci_lo, ci_hi


def _format_ax(ax, title, xlabel="Time (days)", ylabel="Survival probability"):
    ax.set_title(title, fontweight="bold")
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_ylim(-0.02, 1.02)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)


def _add_at_risk_table(ax, grid, d_pos, d_neg, duration_col, max_ticks=6):
    """Add number-at-risk annotation below a KM panel."""
    tick_idxs = np.linspace(0, len(grid) - 1, max_ticks, dtype=int)
    tick_times = grid[tick_idxs]
    n_pos = [int((d_pos[duration_col] >= t).sum()) for t in tick_times]
    n_neg = [int((d_neg[duration_col] >= t).sum()) for t in tick_times]
    table_text = "At risk\n"
    table_text += "  Mut+: " + "  ".join(f"{n:>4d}" for n in n_pos) + "\n"
    table_text += "  Mut-: " + "  ".join(f"{n:>4d}" for n in n_neg)
    ax.set_xticks(tick_times)
    ax.set_xticklabels([f"{int(t)}" for t in tick_times])
    ax.annotate(table_text, xy=(0, -0.28), xycoords="axes fraction",
                fontsize=8, fontfamily="monospace", va="top")


def _p_str(p):
    return f"p={p:.2e}" if p < 0.001 else f"p={p:.3f}"


print("Helper functions defined.")

# %%
# ── Load all 4 IPTW dataframes & prepare weighted data per (spec, cancer_type) ──

needed_types = set(ct for _, ct in TOP_TRACK1) | set(ct for _, ct in TOP_TRACK2)

# weighted_cache[(spec_label, cancer_type)] -> weighted DataFrame
weighted_cache = {}

for matching, ps_model in SPECS:
    spec_label = f"{matching}_{ps_model}"
    iptw_file = os.path.join(MARKER_PATH, f"IPTW_df_{spec_label}.csv")
    print(f"\n{'='*60}")
    print(f"Loading {spec_label}: {iptw_file}")

    try:
        spec_df = pd.read_csv(iptw_file)
    except FileNotFoundError:
        print(f"  FILE NOT FOUND — skipping this spec")
        continue

    n_ici = int((spec_df["PX_on_ICI"] == 1).sum())
    n_ctrl = int((spec_df["PX_on_ICI"] == 0).sum())
    print(f"  {len(spec_df)} rows ({n_ici} ICI, {n_ctrl} non-ICI)")

    for ct in sorted(needed_types):
        print(f"  Preparing {ct}...", end=" ")
        try:
            wdf = prepare_weighted_df(spec_df, ct)
            weighted_cache[(spec_label, ct)] = wdf
            n = len(wdf)
            n_i = int((wdf["PX_on_ICI"] == 1).sum())
            print(f"{n} patients ({n_i} ICI, {n - n_i} non-ICI)")
        except Exception as e:
            print(f"ERROR: {e}")

print(f"\nCached {len(weighted_cache)} (spec, cancer_type) combinations")

# %%
# ── Track 1: Two-panel KM (OVL-weighted vs Unweighted), ICI-only ────

def plot_track1_km(df, marker, cancer_type, spec_label, out_dir):
    """Two-panel: Overlap-weighted (left) vs Unweighted (right), ICI cohort."""
    ici = df.loc[df["PX_on_ICI"] == 1,
                 ["tt_death", "death", marker, "IPTW_GEN_OVL"]].dropna().copy()
    ici[marker] = (pd.to_numeric(ici[marker], errors="coerce").fillna(0) > 0).astype(int)
    d_pos = ici[ici[marker] == 1]
    d_neg = ici[ici[marker] == 0]

    if len(d_pos) < 5 or len(d_neg) < 5:
        print(f"    Skip {marker}/{cancer_type}: pos={len(d_pos)}, neg={len(d_neg)}")
        return

    tmax = float(ici["tt_death"].max())
    if MAX_TIME_DAYS is not None:
        tmax = min(tmax, MAX_TIME_DAYS)
    grid = np.linspace(0, tmax, GRID_POINTS)

    # log-rank tests
    lr_ovl = logrank_test(
        d_pos["tt_death"], d_neg["tt_death"],
        event_observed_A=d_pos["death"], event_observed_B=d_neg["death"],
        weights_A=d_pos["IPTW_GEN_OVL"], weights_B=d_neg["IPTW_GEN_OVL"])
    lr_u = logrank_test(
        d_pos["tt_death"], d_neg["tt_death"],
        event_observed_A=d_pos["death"], event_observed_B=d_neg["death"])

    fig, (ax_ovl, ax_u) = plt.subplots(1, 2, figsize=(14, 5.5), sharey=True)

    # Left: Overlap-weighted (bootstrap)
    med_p, lo_p, hi_p = bootstrap_weighted_km(
        d_pos["tt_death"], d_pos["death"], d_pos["IPTW_GEN_OVL"], grid, N_BOOT, SEED)
    med_n, lo_n, hi_n = bootstrap_weighted_km(
        d_neg["tt_death"], d_neg["death"], d_neg["IPTW_GEN_OVL"], grid, N_BOOT, SEED + 1)

    ax_ovl.plot(grid, med_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_ovl.fill_between(grid, lo_p, hi_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_ovl.plot(grid, med_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_ovl.fill_between(grid, lo_n, hi_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_ovl, f"Overlap-Weighted (1−ps)\n{_p_str(lr_ovl.p_value)}")
    ax_ovl.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_ovl, grid, d_pos, d_neg, "tt_death")

    # Right: Unweighted
    s_p, ci_lo_p, ci_hi_p = unweighted_km(d_pos["tt_death"], d_pos["death"], grid)
    s_n, ci_lo_n, ci_hi_n = unweighted_km(d_neg["tt_death"], d_neg["death"], grid)

    ax_u.plot(grid, s_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_u.fill_between(grid, ci_lo_p, ci_hi_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_u.plot(grid, s_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_u.fill_between(grid, ci_lo_n, ci_hi_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_u, f"Unweighted\n{_p_str(lr_u.p_value)}", ylabel="")
    ax_u.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_u, grid, d_pos, d_neg, "tt_death")

    fig.suptitle(f"Track 1 — {marker} ({cancer_type})\n[{spec_label}]",
                 fontsize=14, fontweight="bold", y=1.04)
    fig.tight_layout()

    out_path = os.path.join(out_dir, f"T1_{cancer_type}_{marker}_{spec_label}_KM.png")
    fig.savefig(out_path, bbox_inches="tight")
    print(f"    Saved: {out_path}")
    plt.close(fig)


for matching, ps_model in SPECS:
    spec_label = f"{matching}_{ps_model}"
    t1_dir = os.path.join(OUT_ROOT, f"track1/{spec_label}/")
    os.makedirs(t1_dir, exist_ok=True)

    print(f"\n{'='*60}")
    print(f"Track 1 KM curves — {spec_label}")
    print(f"{'='*60}")

    for marker, ct in tqdm(TOP_TRACK1, desc=f"T1 {spec_label}"):
        key = (spec_label, ct)
        if key not in weighted_cache:
            print(f"  Skip {marker}/{ct}: no data for {spec_label}")
            continue
        wdf = weighted_cache[key]
        if marker not in wdf.columns:
            print(f"  Skip {marker}: column not in data")
            continue
        try:
            plot_track1_km(wdf, marker, ct, spec_label, t1_dir)
        except Exception as e:
            print(f"  ERROR {marker}/{ct}: {e}")

# %%
# ── Track 2: Four-panel KM (ICI vs Non-ICI × OVL-weighted vs Unweighted) ─────

def plot_track2_km(df, marker, cancer_type, spec_label, out_dir):
    """Four-panel: rows = ICI / Non-ICI, cols = OVL-weighted / Unweighted."""
    cols = ["tt_death", "death", "PX_on_ICI", marker, "IPTW_OVL"]
    d = df[cols].dropna().copy()
    d[marker] = (pd.to_numeric(d[marker], errors="coerce").fillna(0) > 0).astype(int)

    ici = d[d["PX_on_ICI"] == 1]
    nonici = d[d["PX_on_ICI"] == 0]
    groups = {
        "ICI_pos": ici[ici[marker] == 1],
        "ICI_neg": ici[ici[marker] == 0],
        "nonICI_pos": nonici[nonici[marker] == 1],
        "nonICI_neg": nonici[nonici[marker] == 0],
    }
    for key, grp in groups.items():
        if len(grp) < 5:
            print(f"    Skip {marker}/{cancer_type}: {key} n={len(grp)}")
            return

    tmax = float(d["tt_death"].max())
    if MAX_TIME_DAYS is not None:
        tmax = min(tmax, MAX_TIME_DAYS)
    grid = np.linspace(0, tmax, GRID_POINTS)

    # log-rank tests
    def _lr(a, b, wcol):
        return logrank_test(a["tt_death"], b["tt_death"],
                            event_observed_A=a["death"], event_observed_B=b["death"],
                            weights_A=a[wcol], weights_B=b[wcol])
    def _lr_u(a, b):
        return logrank_test(a["tt_death"], b["tt_death"],
                            event_observed_A=a["death"], event_observed_B=b["death"])

    p_ici_ovl = _lr(groups["ICI_pos"], groups["ICI_neg"], "IPTW_OVL")
    p_ici_u = _lr_u(groups["ICI_pos"], groups["ICI_neg"])
    p_ni_ovl = _lr(groups["nonICI_pos"], groups["nonICI_neg"], "IPTW_OVL")
    p_ni_u = _lr_u(groups["nonICI_pos"], groups["nonICI_neg"])

    fig, axes = plt.subplots(2, 2, figsize=(14, 11), sharey=True, sharex=True)
    (ax_ici_ovl, ax_ici_u) = axes[0]
    (ax_ni_ovl, ax_ni_u) = axes[1]

    def _panel(ax, d_pos, d_neg, weight_col, p_val, title, show_ylabel=True):
        if weight_col is not None:
            m_p, l_p, h_p = bootstrap_weighted_km(
                d_pos["tt_death"], d_pos["death"], d_pos[weight_col], grid, N_BOOT, SEED)
            m_n, l_n, h_n = bootstrap_weighted_km(
                d_neg["tt_death"], d_neg["death"], d_neg[weight_col], grid, N_BOOT, SEED + 1)
        else:
            m_p, l_p, h_p = unweighted_km(d_pos["tt_death"], d_pos["death"], grid)
            m_n, l_n, h_n = unweighted_km(d_neg["tt_death"], d_neg["death"], grid)

        ax.plot(grid, m_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
        ax.fill_between(grid, l_p, h_p, color=COLOR_POS, alpha=CI_ALPHA)
        ax.plot(grid, m_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
        ax.fill_between(grid, l_n, h_n, color=COLOR_NEG, alpha=CI_ALPHA)
        ylabel = "Survival probability" if show_ylabel else ""
        _format_ax(ax, f"{title}\n{_p_str(p_val)}", ylabel=ylabel)
        ax.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
        _add_at_risk_table(ax, grid, d_pos, d_neg, "tt_death")

    # Row 1: ICI-treated
    _panel(ax_ici_ovl, groups["ICI_pos"], groups["ICI_neg"],
           "IPTW_OVL", p_ici_ovl.p_value, "ICI-Treated — Overlap-Weighted")
    _panel(ax_ici_u, groups["ICI_pos"], groups["ICI_neg"],
           None, p_ici_u.p_value, "ICI-Treated — Unweighted", show_ylabel=False)

    # Row 2: Non-ICI
    _panel(ax_ni_ovl, groups["nonICI_pos"], groups["nonICI_neg"],
           "IPTW_OVL", p_ni_ovl.p_value, "Non-ICI — Overlap-Weighted")
    _panel(ax_ni_u, groups["nonICI_pos"], groups["nonICI_neg"],
           None, p_ni_u.p_value, "Non-ICI — Unweighted", show_ylabel=False)

    fig.suptitle(f"Track 2 — {marker} ({cancer_type})\n[{spec_label}]",
                 fontsize=14, fontweight="bold", y=1.02)
    fig.tight_layout()

    out_path = os.path.join(out_dir, f"T2_{cancer_type}_{marker}_{spec_label}_KM.png")
    fig.savefig(out_path, bbox_inches="tight")
    print(f"    Saved: {out_path}")
    plt.close(fig)


for matching, ps_model in SPECS:
    spec_label = f"{matching}_{ps_model}"
    t2_dir = os.path.join(OUT_ROOT, f"track2/{spec_label}/")
    os.makedirs(t2_dir, exist_ok=True)

    print(f"\n{'='*60}")
    print(f"Track 2 KM curves — {spec_label}")
    print(f"{'='*60}")

    for marker, ct in tqdm(TOP_TRACK2, desc=f"T2 {spec_label}"):
        key = (spec_label, ct)
        if key not in weighted_cache:
            print(f"  Skip {marker}/{ct}: no data for {spec_label}")
            continue
        wdf = weighted_cache[key]
        if marker not in wdf.columns:
            print(f"  Skip {marker}: column not in data")
            continue
        try:
            plot_track2_km(wdf, marker, ct, spec_label, t2_dir)
        except Exception as e:
            print(f"  ERROR {marker}/{ct}: {e}")

print(f"\nAll done. Figures saved to {OUT_ROOT}")

# %% [markdown]
# # Track 1b: Prognostic-Score-Adjusted KM Comparisons
#
# Three-panel figures showing the effect of prognostic adjustment:
# - **Left**: Unweighted KM (what Track 1a sees)
# - **Middle**: OVL-weighted KM (Track 1a sensitivity)
# - **Right**: Prognostic-score-adjusted KM (what Track 1b effectively tests)
#
# The right panel uses IPW on the **marker** (not treatment): weights balance the embedding-derived prognostic score between marker+ and marker- groups, removing the confounding effect of baseline prognosis.
#
# Three categories of markers:
# 1. **Confounding-robust** (sig in both 1a and 1b): adjustment doesn't change the picture
# 2. **1a-only** (sig in 1a but not 1b): the marker effect is explained by the prognostic score
# 3. **1b-only** (sig in 1b but not 1a cross-scheme): progAdj reveals or preserves signal that cross-scheme filter removes

# %%
# ── Track 1b: Prognostic-score-adjusted KM ────────────────────────────
from lifelines import CoxPHFitter
from sklearn.decomposition import PCA

PROG_SCORE_N_PCS = 20
PROG_SCORE_PENALIZER = 0.1

# Marker categories for Track 1b comparison
T1B_CONFOUNDING_ROBUST = [
    # Sig in both 1a cross-scheme AND 1b (highest confidence)
    ("ARID1A_SNV",          "pan_cancer"),
    ("PBRM1_SNV",           "pan_cancer"),
    ("MLH1_SNV",            "pan_cancer"),
    ("WHSC1_SNV",           "pan_cancer"),
    ("IDH1_SNV",            "pan_cancer"),
    ("NF1_DEL",             "SOFT_TISSUE"),
]

T1B_1A_ONLY = [
    # Sig in 1a cross-scheme but NOT in 1b (adjustment kills signal)
    ("EPCAM_DEL",           "BREAST"),
    ("ERG_TMPRSS2_FUSION",  "pan_cancer"),
    ("KDR_AMP",             "BRAIN"),
    ("TMPRSS2_ERG_FUSION",  "pan_cancer"),
]

T1B_1B_ONLY = [
    # Sig in 1b but NOT in 1a cross-scheme (adjustment reveals/preserves signal)
    ("BRCA1_SNV",   "pan_cancer"),
    ("CDKN2A_DEL",  "pan_cancer"),
    ("KMT2D_SNV",   "pan_cancer"),
    ("EZH2_SNV",    "pan_cancer"),
    ("SETD2_SNV",   "pan_cancer"),
]


def compute_prognostic_score(df_ici, embedding_cols, n_pcs=PROG_SCORE_N_PCS):
    """PCA on embeddings -> CoxPH -> prognostic score (log partial hazard)."""
    # PCA on embeddings
    avail = [c for c in embedding_cols if c in df_ici.columns]
    if len(avail) < n_pcs:
        raise ValueError(f"Only {len(avail)} embedding cols, need {n_pcs}")

    X_emb = df_ici[avail].fillna(0).values
    pca = PCA(n_components=n_pcs, random_state=42)
    pcs = pca.fit_transform(X_emb)
    pc_names = [f"_prog_PC_{i}" for i in range(n_pcs)]
    for i, name in enumerate(pc_names):
        df_ici[name] = pcs[:, i]

    # Fit CoxPH: survival ~ PCs
    fit_df = df_ici[["tt_death", "death"] + pc_names].dropna()
    cph = CoxPHFitter(penalizer=PROG_SCORE_PENALIZER)
    with warnings.catch_warnings():
        warnings.filterwarnings("ignore")
        cph.fit(fit_df, duration_col="tt_death", event_col="death")

    lp = cph.predict_partial_hazard(df_ici[pc_names].fillna(0))
    return np.log(lp.values.ravel() + 1e-10)


def compute_marker_ipw(marker_vals, prog_score, eps=0.02):
    """IPW weights to balance prognostic score between marker+ and marker-."""
    X = prog_score.reshape(-1, 1)
    y = marker_vals.astype(int)
    if y.sum() < 5 or (1 - y).sum() < 5:
        return np.ones_like(y, dtype=float)
    lr = LogisticRegression(penalty=None, solver="lbfgs", max_iter=1000)
    lr.fit(X, y)
    p = lr.predict_proba(X)[:, 1].clip(eps, 1 - eps)
    # Stabilized ATE-style weights for marker
    prev = y.mean()
    w = np.where(y == 1, prev / p, (1 - prev) / (1 - p))
    lo, hi = np.percentile(w, (1, 99))
    return np.clip(w, lo, hi)


def plot_track1b_km(df, marker, cancer_type, spec_label, out_dir, category_label=""):
    """Three-panel: Unweighted / OVL-weighted / Prog-Score-Adjusted KM."""
    # Find embedding columns
    embed_cols = [c for c in df.columns
                  if ('IMAGING' in c) or ('PATHOLOGY' in c) or ('CLINICIAN' in c)]

    ici = df.loc[df["PX_on_ICI"] == 1].copy()
    ici[marker] = (pd.to_numeric(ici[marker], errors="coerce").fillna(0) > 0).astype(int)

    if ici[marker].sum() < 5 or (1 - ici[marker]).sum() < 5:
        print(f"    Skip {marker}/{cancer_type}: insufficient marker prevalence")
        return

    # Compute prognostic score and marker IPW
    if len(embed_cols) >= PROG_SCORE_N_PCS:
        try:
            prog_score = compute_prognostic_score(ici, embed_cols)
            ici["marker_ipw"] = compute_marker_ipw(ici[marker].values, prog_score)
        except Exception as e:
            print(f"    Skip {marker}/{cancer_type} prog score: {e}")
            return
    else:
        print(f"    Skip {marker}/{cancer_type}: only {len(embed_cols)} embedding cols")
        return

    cols_needed = ["tt_death", "death", marker, "IPTW_GEN_OVL", "marker_ipw"]
    d = ici[cols_needed].dropna()
    d_pos = d[d[marker] == 1]
    d_neg = d[d[marker] == 0]

    if len(d_pos) < 5 or len(d_neg) < 5:
        print(f"    Skip {marker}/{cancer_type}: pos={len(d_pos)}, neg={len(d_neg)}")
        return

    tmax = float(d["tt_death"].max())
    if MAX_TIME_DAYS:
        tmax = min(tmax, MAX_TIME_DAYS)
    grid = np.linspace(0, tmax, GRID_POINTS)

    # Log-rank tests
    lr_u = logrank_test(d_pos["tt_death"], d_neg["tt_death"],
                        event_observed_A=d_pos["death"], event_observed_B=d_neg["death"])
    lr_ovl = logrank_test(d_pos["tt_death"], d_neg["tt_death"],
                          event_observed_A=d_pos["death"], event_observed_B=d_neg["death"],
                          weights_A=d_pos["IPTW_GEN_OVL"], weights_B=d_neg["IPTW_GEN_OVL"])
    lr_adj = logrank_test(d_pos["tt_death"], d_neg["tt_death"],
                          event_observed_A=d_pos["death"], event_observed_B=d_neg["death"],
                          weights_A=d_pos["marker_ipw"], weights_B=d_neg["marker_ipw"])

    fig, (ax_u, ax_ovl, ax_adj) = plt.subplots(1, 3, figsize=(20, 5.5), sharey=True)

    # Panel 1: Unweighted
    s_p, ci_lo_p, ci_hi_p = unweighted_km(d_pos["tt_death"], d_pos["death"], grid)
    s_n, ci_lo_n, ci_hi_n = unweighted_km(d_neg["tt_death"], d_neg["death"], grid)
    ax_u.plot(grid, s_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_u.fill_between(grid, ci_lo_p, ci_hi_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_u.plot(grid, s_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_u.fill_between(grid, ci_lo_n, ci_hi_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_u, f"Unweighted\n{_p_str(lr_u.p_value)}")
    ax_u.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_u, grid, d_pos, d_neg, "tt_death")

    # Panel 2: OVL-weighted
    m_p, l_p, h_p = bootstrap_weighted_km(
        d_pos["tt_death"], d_pos["death"], d_pos["IPTW_GEN_OVL"], grid, N_BOOT, SEED)
    m_n, l_n, h_n = bootstrap_weighted_km(
        d_neg["tt_death"], d_neg["death"], d_neg["IPTW_GEN_OVL"], grid, N_BOOT, SEED + 1)
    ax_ovl.plot(grid, m_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_ovl.fill_between(grid, l_p, h_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_ovl.plot(grid, m_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_ovl.fill_between(grid, l_n, h_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_ovl, f"OVL-Weighted\n{_p_str(lr_ovl.p_value)}", ylabel="")
    ax_ovl.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_ovl, grid, d_pos, d_neg, "tt_death")

    # Panel 3: Prog-score-adjusted (marker IPW)
    m_p, l_p, h_p = bootstrap_weighted_km(
        d_pos["tt_death"], d_pos["death"], d_pos["marker_ipw"], grid, N_BOOT, SEED)
    m_n, l_n, h_n = bootstrap_weighted_km(
        d_neg["tt_death"], d_neg["death"], d_neg["marker_ipw"], grid, N_BOOT, SEED + 1)
    ax_adj.plot(grid, m_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_adj.fill_between(grid, l_p, h_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_adj.plot(grid, m_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_adj.fill_between(grid, l_n, h_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_adj, f"Prog-Score-Adjusted\n{_p_str(lr_adj.p_value)}", ylabel="")
    ax_adj.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_adj, grid, d_pos, d_neg, "tt_death")

    cat_str = f" [{category_label}]" if category_label else ""
    fig.suptitle(f"Track 1b — {marker} ({cancer_type}){cat_str}\n[{spec_label}]",
                 fontsize=14, fontweight="bold", y=1.04)
    fig.tight_layout()

    out_path = os.path.join(out_dir, f"T1b_{cancer_type}_{marker}_{spec_label}_KM.png")
    fig.savefig(out_path, bbox_inches="tight")
    print(f"    Saved: {out_path}")
    plt.close(fig)


# ── Run Track 1b KM curves ───────────────────────────────────────────
all_t1b_markers = (
    [(m, ct, "confounding-robust") for m, ct in T1B_CONFOUNDING_ROBUST] +
    [(m, ct, "1a-only (adj kills signal)") for m, ct in T1B_1A_ONLY] +
    [(m, ct, "1b-only (adj reveals signal)") for m, ct in T1B_1B_ONLY]
)

for matching, ps_model in SPECS:
    spec_label = f"{matching}_{ps_model}"
    t1b_dir = os.path.join(OUT_ROOT, f"track1b/{spec_label}/")
    os.makedirs(t1b_dir, exist_ok=True)

    print(f"\n{'='*60}")
    print(f"Track 1b KM curves — {spec_label}")
    print(f"{'='*60}")

    for marker, ct, cat in tqdm(all_t1b_markers, desc=f"T1b {spec_label}"):
        key = (spec_label, ct)
        if key not in weighted_cache:
            print(f"  Skip {marker}/{ct}: no data for {spec_label}")
            continue
        wdf = weighted_cache[key]
        if marker not in wdf.columns:
            print(f"  Skip {marker}: column not in data")
            continue
        try:
            plot_track1b_km(wdf, marker, ct, spec_label, t1b_dir, category_label=cat)
        except Exception as e:
            print(f"  ERROR {marker}/{ct}: {e}")

# %% [markdown]
# # Scheme-Discordant Markers: OVL vs Unweighted
#
# KM curves for markers significant under one weighting scheme but not the other.
# These visualizations help explain *why* a marker is scheme-discordant — e.g., OVL
# downweighting extreme-propensity patients may attenuate or amplify specific signals.
#
# **Track 1a**: 60 markers discordant between unweighted and OVL (55% of all sig hits)
# - 38 unweighted-only (mostly pan-cancer) — OVL is too conservative
# - 22 OVL-only (mostly BRAIN DELs) — potential OVL artifact
#
# **Track 2**: 6 markers discordant between noIPTW and OVL (50% of all sig hits)
# - All borderline FDR (0.03-0.05), scheme tips them over/under threshold

# %%
# ── Scheme-Discordant Marker KM Curves ────────────────────────────────

# Track 1a discordant: sig in unweighted XOR OVL
DISCORDANT_T1A = [
    # Notable unweighted-only (pan-cancer) — well-known genes lost under OVL
    ("BRCA1_SNV",    "pan_cancer",  "unweighted-only"),
    ("CDKN2A_DEL",   "pan_cancer",  "unweighted-only"),
    ("CDKN2B_DEL",   "pan_cancer",  "unweighted-only"),
    ("EP300_SNV",    "pan_cancer",  "unweighted-only"),
    ("KMT2D_SNV",    "pan_cancer",  "unweighted-only"),
    ("SETD2_SNV",    "pan_cancer",  "unweighted-only"),
    ("ERBB4_SNV",    "pan_cancer",  "unweighted-only"),
    # Notable OVL-only (pan-cancer)
    ("BRCA1_SV",     "pan_cancer",  "OVL-only"),
    ("FANCG_AMP",    "pan_cancer",  "OVL-only"),
    ("RINT1_SNV",    "pan_cancer",  "OVL-only"),
    # BRAIN OVL-only DEL cluster (suspicious)
    ("BAP1_DEL",     "BRAIN",       "OVL-only (BRAIN DEL cluster)"),
    ("CDKN2A_DEL",   "BRAIN",       "OVL-only (BRAIN DEL cluster)"),
    ("SETD2_DEL",    "BRAIN",       "OVL-only (BRAIN DEL cluster)"),
]

# Track 2 discordant: sig in noIPTW XOR OVL
DISCORDANT_T2 = [
    # OVL-only
    ("NOTCH2_DEL",   "BREAST",      "OVL-only"),
    ("ARID2_AMP",    "pan_cancer",  "OVL-only"),
    ("KMT2D_AMP",    "pan_cancer",  "OVL-only"),
    # noIPTW-only
    ("GLI2_AMP",     "pan_cancer",  "noIPTW-only"),
    ("RET_AMP",      "pan_cancer",  "noIPTW-only"),
    ("TCF7L2_AMP",   "pan_cancer",  "noIPTW-only"),
]


def plot_discordant_t1_km(df, marker, cancer_type, spec_label, out_dir, disc_label=""):
    """Two-panel KM for scheme-discordant Track 1a markers (same as standard T1)."""
    ici = df.loc[df["PX_on_ICI"] == 1,
                 ["tt_death", "death", marker, "IPTW_GEN_OVL"]].dropna().copy()
    ici[marker] = (pd.to_numeric(ici[marker], errors="coerce").fillna(0) > 0).astype(int)
    d_pos = ici[ici[marker] == 1]
    d_neg = ici[ici[marker] == 0]

    if len(d_pos) < 5 or len(d_neg) < 5:
        print(f"    Skip {marker}/{cancer_type}: pos={len(d_pos)}, neg={len(d_neg)}")
        return

    tmax = float(ici["tt_death"].max())
    if MAX_TIME_DAYS:
        tmax = min(tmax, MAX_TIME_DAYS)
    grid = np.linspace(0, tmax, GRID_POINTS)

    lr_ovl = logrank_test(
        d_pos["tt_death"], d_neg["tt_death"],
        event_observed_A=d_pos["death"], event_observed_B=d_neg["death"],
        weights_A=d_pos["IPTW_GEN_OVL"], weights_B=d_neg["IPTW_GEN_OVL"])
    lr_u = logrank_test(
        d_pos["tt_death"], d_neg["tt_death"],
        event_observed_A=d_pos["death"], event_observed_B=d_neg["death"])

    fig, (ax_ovl, ax_u) = plt.subplots(1, 2, figsize=(14, 5.5), sharey=True)

    # Left: OVL-weighted
    m_p, l_p, h_p = bootstrap_weighted_km(
        d_pos["tt_death"], d_pos["death"], d_pos["IPTW_GEN_OVL"], grid, N_BOOT, SEED)
    m_n, l_n, h_n = bootstrap_weighted_km(
        d_neg["tt_death"], d_neg["death"], d_neg["IPTW_GEN_OVL"], grid, N_BOOT, SEED + 1)
    ax_ovl.plot(grid, m_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_ovl.fill_between(grid, l_p, h_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_ovl.plot(grid, m_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_ovl.fill_between(grid, l_n, h_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_ovl, f"OVL-Weighted\n{_p_str(lr_ovl.p_value)}")
    ax_ovl.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_ovl, grid, d_pos, d_neg, "tt_death")

    # Right: Unweighted
    s_p, ci_lo_p, ci_hi_p = unweighted_km(d_pos["tt_death"], d_pos["death"], grid)
    s_n, ci_lo_n, ci_hi_n = unweighted_km(d_neg["tt_death"], d_neg["death"], grid)
    ax_u.plot(grid, s_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
    ax_u.fill_between(grid, ci_lo_p, ci_hi_p, color=COLOR_POS, alpha=CI_ALPHA)
    ax_u.plot(grid, s_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
    ax_u.fill_between(grid, ci_lo_n, ci_hi_n, color=COLOR_NEG, alpha=CI_ALPHA)
    _format_ax(ax_u, f"Unweighted\n{_p_str(lr_u.p_value)}", ylabel="")
    ax_u.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
    _add_at_risk_table(ax_u, grid, d_pos, d_neg, "tt_death")

    fig.suptitle(f"DISCORDANT T1a — {marker} ({cancer_type})\n{disc_label} | [{spec_label}]",
                 fontsize=14, fontweight="bold", y=1.04)
    fig.tight_layout()

    out_path = os.path.join(out_dir, f"DISC_T1_{cancer_type}_{marker}_{spec_label}_KM.png")
    fig.savefig(out_path, bbox_inches="tight")
    print(f"    Saved: {out_path}")
    plt.close(fig)


def plot_discordant_t2_km(df, marker, cancer_type, spec_label, out_dir, disc_label=""):
    """Four-panel KM for scheme-discordant Track 2 markers (same as standard T2)."""
    cols = ["tt_death", "death", "PX_on_ICI", marker, "IPTW_OVL"]
    d = df[cols].dropna().copy()
    d[marker] = (pd.to_numeric(d[marker], errors="coerce").fillna(0) > 0).astype(int)

    ici = d[d["PX_on_ICI"] == 1]
    nonici = d[d["PX_on_ICI"] == 0]
    groups = {
        "ICI_pos": ici[ici[marker] == 1],   "ICI_neg": ici[ici[marker] == 0],
        "nonICI_pos": nonici[nonici[marker] == 1], "nonICI_neg": nonici[nonici[marker] == 0],
    }
    for key, grp in groups.items():
        if len(grp) < 5:
            print(f"    Skip {marker}/{cancer_type}: {key} n={len(grp)}")
            return

    tmax = float(d["tt_death"].max())
    if MAX_TIME_DAYS:
        tmax = min(tmax, MAX_TIME_DAYS)
    grid = np.linspace(0, tmax, GRID_POINTS)

    def _lr(a, b, wcol):
        return logrank_test(a["tt_death"], b["tt_death"],
                            event_observed_A=a["death"], event_observed_B=b["death"],
                            weights_A=a[wcol], weights_B=b[wcol])
    def _lr_u(a, b):
        return logrank_test(a["tt_death"], b["tt_death"],
                            event_observed_A=a["death"], event_observed_B=b["death"])

    p_ici_ovl = _lr(groups["ICI_pos"], groups["ICI_neg"], "IPTW_OVL")
    p_ici_u = _lr_u(groups["ICI_pos"], groups["ICI_neg"])
    p_ni_ovl = _lr(groups["nonICI_pos"], groups["nonICI_neg"], "IPTW_OVL")
    p_ni_u = _lr_u(groups["nonICI_pos"], groups["nonICI_neg"])

    fig, axes = plt.subplots(2, 2, figsize=(14, 11), sharey=True, sharex=True)
    (ax_ici_ovl, ax_ici_u) = axes[0]
    (ax_ni_ovl, ax_ni_u) = axes[1]

    def _panel(ax, d_pos, d_neg, weight_col, p_val, title, show_ylabel=True):
        if weight_col is not None:
            m_p, l_p, h_p = bootstrap_weighted_km(
                d_pos["tt_death"], d_pos["death"], d_pos[weight_col], grid, N_BOOT, SEED)
            m_n, l_n, h_n = bootstrap_weighted_km(
                d_neg["tt_death"], d_neg["death"], d_neg[weight_col], grid, N_BOOT, SEED + 1)
        else:
            m_p, l_p, h_p = unweighted_km(d_pos["tt_death"], d_pos["death"], grid)
            m_n, l_n, h_n = unweighted_km(d_neg["tt_death"], d_neg["death"], grid)
        ax.plot(grid, m_p, color=COLOR_POS, lw=2, label=f"Mutant (n={len(d_pos)})")
        ax.fill_between(grid, l_p, h_p, color=COLOR_POS, alpha=CI_ALPHA)
        ax.plot(grid, m_n, color=COLOR_NEG, lw=2, label=f"Wild-type (n={len(d_neg)})")
        ax.fill_between(grid, l_n, h_n, color=COLOR_NEG, alpha=CI_ALPHA)
        ylabel = "Survival probability" if show_ylabel else ""
        _format_ax(ax, f"{title}\n{_p_str(p_val)}", ylabel=ylabel)
        ax.legend(loc="lower left", frameon=True, fancybox=True, framealpha=0.9)
        _add_at_risk_table(ax, grid, d_pos, d_neg, "tt_death")

    _panel(ax_ici_ovl, groups["ICI_pos"], groups["ICI_neg"],
           "IPTW_OVL", p_ici_ovl.p_value, "ICI — OVL-Weighted")
    _panel(ax_ici_u, groups["ICI_pos"], groups["ICI_neg"],
           None, p_ici_u.p_value, "ICI — Unweighted", show_ylabel=False)
    _panel(ax_ni_ovl, groups["nonICI_pos"], groups["nonICI_neg"],
           "IPTW_OVL", p_ni_ovl.p_value, "Non-ICI — OVL-Weighted")
    _panel(ax_ni_u, groups["nonICI_pos"], groups["nonICI_neg"],
           None, p_ni_u.p_value, "Non-ICI — Unweighted", show_ylabel=False)

    fig.suptitle(f"DISCORDANT T2 — {marker} ({cancer_type})\n{disc_label} | [{spec_label}]",
                 fontsize=14, fontweight="bold", y=1.02)
    fig.tight_layout()

    out_path = os.path.join(out_dir, f"DISC_T2_{cancer_type}_{marker}_{spec_label}_KM.png")
    fig.savefig(out_path, bbox_inches="tight")
    print(f"    Saved: {out_path}")
    plt.close(fig)


# ── Run discordant KM curves ─────────────────────────────────────────
for matching, ps_model in SPECS:
    spec_label = f"{matching}_{ps_model}"

    # Track 1a discordant
    disc_t1_dir = os.path.join(OUT_ROOT, f"discordant_t1/{spec_label}/")
    os.makedirs(disc_t1_dir, exist_ok=True)
    print(f"\n{'='*60}")
    print(f"Discordant Track 1a — {spec_label}")
    print(f"{'='*60}")

    for marker, ct, label in tqdm(DISCORDANT_T1A, desc=f"Disc T1 {spec_label}"):
        key = (spec_label, ct)
        if key not in weighted_cache:
            print(f"  Skip {marker}/{ct}: no data")
            continue
        wdf = weighted_cache[key]
        if marker not in wdf.columns:
            print(f"  Skip {marker}: column not in data")
            continue
        try:
            plot_discordant_t1_km(wdf, marker, ct, spec_label, disc_t1_dir, disc_label=label)
        except Exception as e:
            print(f"  ERROR {marker}/{ct}: {e}")

    # Track 2 discordant
    disc_t2_dir = os.path.join(OUT_ROOT, f"discordant_t2/{spec_label}/")
    os.makedirs(disc_t2_dir, exist_ok=True)
    print(f"\n{'='*60}")
    print(f"Discordant Track 2 — {spec_label}")
    print(f"{'='*60}")

    for marker, ct, label in tqdm(DISCORDANT_T2, desc=f"Disc T2 {spec_label}"):
        key = (spec_label, ct)
        if key not in weighted_cache:
            print(f"  Skip {marker}/{ct}: no data")
            continue
        wdf = weighted_cache[key]
        if marker not in wdf.columns:
            print(f"  Skip {marker}: column not in data")
            continue
        try:
            plot_discordant_t2_km(wdf, marker, ct, spec_label, disc_t2_dir, disc_label=label)
        except Exception as e:
            print(f"  ERROR {marker}/{ct}: {e}")

print(f"\nAll done. Figures saved to {OUT_ROOT}")
